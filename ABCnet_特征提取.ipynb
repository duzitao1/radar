# %% [markdown]
# # 设置参数
# 配置的参数,需要与采集数据时雷达配置的参数一致

# %%
import torch
import os
import numpy as np
import glob
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
from RealTimeCollector.RealTimeCollector import RealTimeCollector

n_RX = 4  # RX天线通道总数
n_samples = 64  # 采样点数
n_chirps = 255  # 每帧脉冲数
N = 64  # 距离向FFT点数
M = 64  # 多普勒向FFT点数
Q = 64  # 角度FFT

c = 3.0e8   # 光速
B = 3999.48e6  # 调频带宽
K = 99.987e12  # 调频斜率
T = B / K  # 调频周期
Tc = 140e-6  # chirp总周期
fs = 2.5e6  # 采样率
f0 = 77e9  # 初始频率
lambda_val = c / f0  # 雷达信号波长
d = lambda_val / 2  # 天线阵列间距

numADCBits = 16 # ADC位数
numLanes = 4    # 通道数
isReal = 0      # 是否为实数

# 是否静态杂波滤除
is_static_clutter_removal = 1

num_classes = 4 # 类别数
num_samples = 200
n_frames = 30

distance_axis = torch.arange(0, N) * fs * c / (2 * K * N)   # 距离轴
velocity_axis = torch.arange(-M/2, M/2) * lambda_val / Tc / M / 2   # 速度轴

rtc = RealTimeCollector(ip_address='127.0.0.7')

# %% [markdown]
# # 特征提取
# 需要修改的参数有：
# - `num_classes`：分类的类别数
# - `directory_path`：数据集的路径
# ## 数据集要求
# - 数据集的文件夹名为类别的标签
#
# ```shell
# |-- 1
# |   |-- 1.bin
# |   |-- 2.bin
# |   |-- ...
# |-- 2
# |   |-- 1.bin
# |   |-- 2.bin
# |   |-- ...
# |-- ...
# ```

# %%
import os
import numpy as np
import glob
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio

num_classes = 4 # 类别数
num_samples = 1000   # 每个类别的样本数
n_frames = 30   # 每个样本的帧数

# 遍历所有类别的文件夹
for label in range(1, num_classes + 1):
    print(f"当前类别为：{label}")
    # directory_path = f'K:/dataset/AA/{label}'
    directory_path = f'K:/dataset/2024_3_22/{label}'
    # 初始化变量
    range_profile = np.zeros((num_samples, n_frames, N), dtype=np.complex128)
    speed_profile = np.zeros((num_samples, n_frames, M), dtype=np.complex128)
    angle_profile = np.zeros((num_samples, n_frames, Q), dtype=np.complex128)


    bin_files = sorted(glob.glob(os.path.join(directory_path, '*.bin')))
    
    # 遍历数据集
    for i, bin_file in enumerate(bin_files):
        filename = os.path.join(directory_path, bin_file)
        print(filename)
        print(f'正在处理第{i+1}个文件')

        # 读取文件
        with open(filename, 'rb') as file:
            adcData = np.fromfile(file, dtype=np.int16)
        
        # 实部虚部结合
        adcData = adcData.reshape(numLanes*2, -1,order='F')
        adcData = adcData[[0,1,2,3],:] + 1j*adcData[[4,5,6,7],:]

        data_radar = np.reshape(adcData, (n_RX, n_samples, n_chirps, n_frames), order='F')

        temp_range_profile, temp_speed_profile, temp_angle_profile = rtc.process_frame(data_radar,clutter_removal='avg')
        
        # 压缩维度
        temp_range_profile = np.squeeze(np.mean(np.abs(temp_range_profile), axis=(0, 2))).T
        temp_speed_profile = np.squeeze(np.mean(np.abs(temp_speed_profile), axis=(0, 1))).T
        temp_angle_profile = np.squeeze(np.mean(np.abs(temp_angle_profile), axis=(1, 2))).T
        
        range_profile[i,:,:] = temp_range_profile
        speed_profile[i,:,:] = temp_speed_profile
        angle_profile[i,:,:] = temp_angle_profile
        
    # 保存.mat文件
    out_path = f'out/test/pyfeature/'
    if not os.path.exists(out_path):
        os.makedirs(out_path)
    
    sio.savemat(out_path + str(label) + '.mat', {'range_profile':range_profile,'speed_profile':speed_profile,'angle_profile':angle_profile})
# Out:
# 当前类别为：1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 24
#      20 speed_profile = np.zeros((num_samples, n_frames, M), dtype=np.complex128)
#      21 angle_profile = np.zeros((num_samples, n_frames, Q), dtype=np.complex128)
# ---> 24 bin_files = sorted(glob.glob(os.path.join(directory_path, '*.bin')))
#      26 # 遍历数据集
#      27 for i, bin_file in enumerate(bin_files):
#
# NameError: name 'directory_path' is not defined

# %%
# 定义特征提取函数(文件路径,需要处理的类别列表,静态杂波滤除方法(列表))
def feature_extraction(directory_path, label_list, num_samples, out_path, clutter_removal):
    
    print(label_list)
    # 遍历类别列表
    for label in label_list:
        
        print(f"当前类别为：{label}")
        path = f'{directory_path}/{label}'   
        print(path)
        
        
        # 初始化变量
        range_profile = np.zeros((num_samples*len(clutter_removal), n_frames, N), dtype=np.complex128)
        speed_profile = np.zeros((num_samples*len(clutter_removal), n_frames, M), dtype=np.complex128)
        angle_profile = np.zeros((num_samples*len(clutter_removal), n_frames, Q), dtype=np.complex128)
        bin_files = sorted(glob.glob(os.path.join(path, '*.bin')))
        print(bin_files)
        # 遍历数据集
        for i, bin_file in enumerate(bin_files):
            if i >= num_samples:
                break
            
            filename = os.path.join(path, f'{i+1}.bin')
            print(filename)
            print(f'正在处理第{i+1}个文件')
            
            

            # 读取文件
            with open(filename, 'rb') as file:
                adcData = np.fromfile(file, dtype=np.int16)
            
            # 实部虚部结合
            adcData = adcData.reshape(numLanes*2, -1,order='F')
            adcData = adcData[[0,1,2,3],:] + 1j*adcData[[4,5,6,7],:]

            data_radar = np.reshape(adcData, (n_RX, n_samples, n_chirps, n_frames), order='F')
            
            # 遍历静态杂波滤除方法
            for j, method in enumerate(clutter_removal):
                temp_range_profile, temp_speed_profile, temp_angle_profile = rtc.process_frame(data_radar,clutter_removal=method,is_squeeze=True)
                
                range_profile[i*len(clutter_removal)+j,:,:] = temp_range_profile
                speed_profile[i*len(clutter_removal)+j,:,:] = temp_speed_profile
                angle_profile[i*len(clutter_removal)+j,:,:] = temp_angle_profile
            
        # 保存.mat文件
        if not os.path.exists(out_path):
            os.makedirs(out_path)
        
        sio.savemat(out_path + str(label) + '.mat', {'range_profile':range_profile,'speed_profile':speed_profile,'angle_profile':angle_profile})

# range_profile, speed_profile, angle_profile = feature_extraction('K:/dataset/AA', [5], 800, 'out/feature/',[None,'avg'])
# feature_extraction('K:/dataset/1000', [5], 1000, 'out/1000/avg/',['avg'])
feature_extraction('K:/dataset/1000', [5], 1000, 'out/1000/None/',['None'])
feature_extraction('K:/dataset/1000', [5], 1000, 'out/1000/mti/',['mti'])
# Out:
# [5]
# 当前类别为：5
# K:/dataset/1000/5
# ['K:/dataset/1000/5\\1.bin', 'K:/dataset/1000/5\\10.bin', 'K:/dataset/1000/5\\100.bin', 'K:/dataset/1000/5\\1000.bin', 'K:/dataset/1000/5\\101.bin', 'K:/dataset/1000/5\\102.bin', 'K:/dataset/1000/5\\103.bin', 'K:/dataset/1000/5\\104.bin', 'K:/dataset/1000/5\\105.bin', 'K:/dataset/1000/5\\106.bin', 'K:/dataset/1000/5\\107.bin', 'K:/dataset/1000/5\\108.bin', 'K:/dataset/1000/5\\109.bin', 'K:/dataset/1000/5\\11.bin', 'K:/dataset/1000/5\\110.bin', 'K:/dataset/1000/5\\111.bin', 'K:/dataset/1000/5\\112.bin', 'K:/dataset/1000/5\\113.bin', 'K:/dataset/1000/5\\114.bin', 'K:/dataset/1000/5\\115.bin', 'K:/dataset/1000/5\\116.bin', 'K:/dataset/1000/5\\117.bin', 'K:/dataset/1000/5\\118.bin', 'K:/dataset/1000/5\\119.bin', 'K:/dataset/1000/5\\12.bin', 'K:/dataset/1000/5\\120.bin', 'K:/dataset/1000/5\\121.bin', 'K:/dataset/1000/5\\122.bin', 'K:/dataset/1000/5\\123.bin', 'K:/dataset/1000/5\\124.bin', 'K:/dataset/1000/5\\125.bin', 'K:/dataset/1000/5\\126.bin', 'K:/dataset/1000/5\\127.bin', 'K:/dataset/1000/5\\128.bin', 'K:/dataset/1000/5\\129.bin', 'K:/dataset/1000/5\\13.bin', 'K:/dataset/1000/5\\130.bin', 'K:/dataset/1000/5\\131.bin', 'K:/dataset/1000/5\\132.bin', 'K:/dataset/1000/5\\133.bin', 'K:/dataset/1000/5\\134.bin', 'K:/dataset/1000/5\\135.bin', 'K:/dataset/1000/5\\136.bin', 'K:/dataset/1000/5\\137.bin', 'K:/dataset/1000/5\\138.bin', 'K:/dataset/1000/5\\139.bin', 'K:/dataset/1000/5\\14.bin', 'K:/dataset/1000/5\\140.bin', 'K:/dataset/1000/5\\141.bin', 'K:/dataset/1000/5\\142.bin', 'K:/dataset/1000/5\\143.bin', 'K:/dataset/1000/5\\144.bin', 'K:/dataset/1000/5\\145.bin', 'K:/dataset/1000/5\\146.bin', 'K:/dataset/1000/5\\147.bin', 'K:/dataset/1000/5\\148.bin', 'K:/dataset/1000/5\\149.bin', 'K:/dataset/1000/5\\15.bin', 'K:/dataset/1000/5\\150.bin', 'K:/dataset/1000/5\\151.bin', 'K:/dataset/1000/5\\152.bin', 'K:/dataset/1000/5\\153.bin', 'K:/dataset/1000/5\\154.bin', 'K:/dataset/1000/5\\155.bin', 'K:/dataset/1000/5\\156.bin', 'K:/dataset/1000/5\\157.bin', 'K:/dataset/1000/5\\158.bin', 'K:/dataset/1000/5\\159.bin', 'K:/dataset/1000/5\\16.bin', 'K:/dataset/1000/5\\160.bin', 'K:/dataset/1000/5\\161.bin', 'K:/dataset/1000/5\\162.bin', 'K:/dataset/1000/5\\163.bin', 'K:/dataset/1000/5\\164.bin', 'K:/dataset/1000/5\\165.bin', 'K:/dataset/1000/5\\166.bin', 'K:/dataset/1000/5\\167.bin', 'K:/dataset/1000/5\\168.bin', 'K:/dataset/1000/5\\169.bin', 'K:/dataset/1000/5\\17.bin', 'K:/dataset/1000/5\\170.bin', 'K:/dataset/1000/5\\171.bin', 'K:/dataset/1000/5\\172.bin', 'K:/dataset/1000/5\\173.bin', 'K:/dataset/1000/5\\174.bin', 'K:/dataset/1000/5\\175.bin', 'K:/dataset/1000/5\\176.bin', 'K:/dataset/1000/5\\177.bin', 'K:/dataset/1000/5\\178.bin', 'K:/dataset/1000/5\\179.bin', 'K:/dataset/1000/5\\18.bin', 'K:/dataset/1000/5\\180.bin', 'K:/dataset/1000/5\\181.bin', 'K:/dataset/1000/5\\182.bin', 'K:/dataset/1000/5\\183.bin', 'K:/dataset/1000/5\\184.bin', 'K:/dataset/1000/5\\185.bin', 'K:/dataset/1000/5\\186.bin', 'K:/dataset/1000/5\\187.bin', 'K:/dataset/1000/5\\188.bin', 'K:/dataset/1000/5\\189.bin', 'K:/dataset/1000/5\\19.bin', 'K:/dataset/1000/5\\190.bin', 'K:/dataset/1000/5\\191.bin', 'K:/dataset/1000/5\\192.bin', 'K:/dataset/1000/5\\193.bin', 'K:/dataset/1000/5\\194.bin', 'K:/dataset/1000/5\\195.bin', 'K:/dataset/1000/5\\196.bin', 'K:/dataset/1000/5\\197.bin', 'K:/dataset/1000/5\\198.bin', 'K:/dataset/1000/5\\199.bin', 'K:/dataset/1000/5\\2.bin', 'K:/dataset/1000/5\\20.bin', 'K:/dataset/1000/5\\200.bin', 'K:/dataset/1000/5\\201.bin', 'K:/dataset/1000/5\\202.bin', 'K:/dataset/1000/5\\203.bin', 'K:/dataset/1000/5\\204.bin', 'K:/dataset/1000/5\\205.bin', 'K:/dataset/1000/5\\206.bin', 'K:/dataset/1000/5\\207.bin', 'K:/dataset/1000/5\\208.bin', 'K:/dataset/1000/5\\209.bin', 'K:/dataset/1000/5\\21.bin', 'K:/dataset/1000/5\\210.bin', 'K:/dataset/1000/5\\211.bin', 'K:/dataset/1000/5\\212.bin', 'K:/dataset/1000/5\\213.bin', 'K:/dataset/1000/5\\214.bin', 'K:/dataset/1000/5\\215.bin', 'K:/dataset/1000/5\\216.bin', 'K:/dataset/1000/5\\217.bin', 'K:/dataset/1000/5\\218. ...
# K:/dataset/1000/5\1.bin
# 正在处理第1个文件
# K:/dataset/1000/5\2.bin
# 正在处理第2个文件
# K:/dataset/1000/5\3.bin
# 正在处理第3个文件
# K:/dataset/1000/5\4.bin
# 正在处理第4个文件
# K:/dataset/1000/5\5.bin
# 正在处理第5个文件
# K:/dataset/1000/5\6.bin
# 正在处理第6个文件
# K:/dataset/1000/5\7.bin
# 正在处理第7个文件
# K:/dataset/1000/5\8.bin
# 正在处理第8个文件
# K:/dataset/1000/5\9.bin
# 正在处理第9个文件
# K:/dataset/1000/5\10.bin
# 正在处理第10个文件
# K:/dataset/1000/5\11.bin
# 正在处理第11个文件
# K:/dataset/1000/5\12.bin
# 正在处理第12个文件
# K:/dataset/1000/5\13.bin
# 正在处理第13个文件
# K:/dataset/1000/5\14.bin
# 正在处理第14个文件
# K:/dataset/1000/5\15.bin
# 正在处理第15个文件
# K:/dataset/1000/5\16.bin
# 正在处理第16个文件
# K:/dataset/1000/5\17.bin
# 正在处理第17个文件
# K:/dataset/1000/5\18.bin
# 正在处理第18个文件
# K:/dataset/1000/5\19.bin
# 正在处理第19个文件
# K:/dataset/1000/5\20.bin
# 正在处理第20个文件
# K:/dataset/1000/5\21.bin
# 正在处理第21个文件
# K:/dataset/1000/5\22.bin
# 正在处理第22个文件
# K:/dataset/1000/5\23.bin
# 正在处理第23个文件
# K:/dataset/1000/5\24.bin
# 正在处理第24个文件
# K:/dataset/1000/5\25.bin
# 正在处理第25个文件
# K:/dataset/1000/5\26.bin
# 正在处理第26个文件
# K:/dataset/1000/5\27.bin
# 正在处理第27个文件
# K:/dataset/1000/5\28.bin
# 正在处理第28个文件
# K:/dataset/1000/5\29.bin
# 正在处理第29个文件
# K:/dataset/1000/5\30.bin
# 正在处理第30个文件
# K:/dataset/1000/5\31.bin
# 正在处理第31个文件
# K:/dataset/1000/5\32.bin
# 正在处理第32个文件
# K:/dataset/1000/5\33.bin
# 正在处理第33个文件
# K:/dataset/1000/5\34.bin
# 正在处理第34个文件
# K:/dataset/1000/5\35.bin
# 正在处理第35个文件
# K:/dataset/1000/5\36.bin
# 正在处理第36个文件
# K:/dataset/1000/5\37.bin
# 正在处理第37个文件
# K:/dataset/1000/5\38.bin
# 正在处理第38个文件
# K:/dataset/1000/5\39.bin
# 正在处理第39个文件
# K:/dataset/1000/5\40.bin
# 正在处理第40个文件
# K:/dataset/1000/5\41.bin
# 正在处理第41个文件
# K:/dataset/1000/5\42.bin
# 正在处理第42个文件
# K:/dataset/1000/5\43.bin
# 正在处理第43个文件
# K:/dataset/1000/5\44.bin
# 正在处理第44个文件
# K:/dataset/1000/5\45.bin
# 正在处理第45个文件
# K:/dataset/1000/5\46.bin
# 正在处理第46个文件
# K:/dataset/1000/5\47.bin
# 正在处理第47个文件
# K:/dataset/1000/5\48.bin
# 正在处理第48个文件
# K:/dataset/1000/5\49.bin
# 正在处理第49个文件
# K:/dataset/1000/5\50.bin
# 正在处理第50个文件
# K:/dataset/1000/5\51.bin
# 正在处理第51个文件
# K:/dataset/1000/5\52.bin
# 正在处理第52个文件
# K:/dataset/1000/5\53.bin
# 正在处理第53个文件
# K:/dataset/1000/5\54.bin
# 正在处理第54个文件
# K:/dataset/1000/5\55.bin
# 正在处理第55个文件
# K:/dataset/1000/5\56.bin
# 正在处理第56个文件
# K:/dataset/1000/5\57.bin
# 正在处理第57个文件
# K:/dataset/1000/5\58.bin
# 正在处理第58个文件
# K:/dataset/1000/5\59.bin
# 正在处理第59个文件
# K:/dataset/1000/5\60.bin
# 正在处理第60个文件
# K:/dataset/1000/5\61.bin
# 正在处理第61个文件
# K:/dataset/1000/5\62.bin
# 正在处理第62个文件
# K:/dataset/1000/5\63.bin
# 正在处理第63个文件
# K:/dataset/1000/5\64.bin
# 正在处理第64个文件
# K:/dataset/1000/5\65.bin
# 正在处理第65个文件
# K:/dataset/1000/5\66.bin
# 正在处理第66个文件
# K:/dataset/1000/5\67.bin
# 正在处理第67个文件
# K:/dataset/1000/5\68.bin
# 正在处理第68个文件
# K:/dataset/1000/5\69.bin
# 正在处理第69个文件
# K:/dataset/1000/5\70.bin
# 正在处理第70个文件
# K:/dataset/1000/5\71.bin
# 正在处理第71个文件
# K:/dataset/1000/5\72.bin
# 正在处理第72个文件
# K:/dataset/1000/5\73.bin
# 正在处理第73个文件
# K:/dataset/1000/5\74.bin
# 正在处理第74个文件
# K:/dataset/1000/5\75.bin
# 正在处理第75个文件
# K:/dataset/1000/5\76.bin
# 正在处理第76个文件
# K:/dataset/1000/5\77.bin
# 正在处理第77个文件
# K:/dataset/1000/5\78.bin
# 正在处理第78个文件
# K:/dataset/1000/5\79.bin
# 正在处理第79个文件
# K:/dataset/1000/5\80.bin
# 正在处理第80个文件
# K:/dataset/1000/5\81.bin
# 正在处理第81个文件
# K:/dataset/1000/5\82.bin
# 正在处理第82个文件
# K:/dataset/1000/5\83.bin
# 正在处理第83个文件
# K:/dataset/1000/5\84.bin
# 正在处理第84个文件
# K:/dataset/1000/5\85.bin
# 正在处理第85个文件
# K:/dataset/1000/5\86.bin
# 正在处理第86个文件
# K:/dataset/1000/5\87.bin
# 正在处理第87个文件
# K:/dataset/1000/5\88.bin
# 正在处理第88个文件
# K:/dataset/1000/5\89.bin
# 正在处理第89个文件
# K:/dataset/1000/5\90.bin
# 正在处理第90个文件
# K:/dataset/1000/5\91.bin
# 正在处理第91个文件
# K:/dataset/1000/5\92.bin
# 正在处理第92个文件
# K:/dataset/1000/5\93.bin
# 正在处理第93个文件
# K:/dataset/1000/5\94.bin
# 正在处理第94个文件
# K:/dataset/1000/5\95.bin
# 正在处理第95个文件
# K:/dataset/1000/5\96.bin
# 正在处理第96个文件
# K:/dataset/1000/5\97.bin
# 正在处理第97个文件
# K:/dataset/1000/5\98.bin
# 正在处理第98个文件
# K:/dataset/1000/5\99.bin
# 正在处理第99个文件
# K:/dataset/1000/5\100.bin
# 正在处理第100个文件
# K:/dataset/1000/5\101.bin
# 正在处理第101个文件
# K:/dataset/1000/5\102.bin
# 正在处理第102个文件
# K:/dataset/1000/5\103.bin
# 正在处理第103个文件
# K:/dataset/1000/5\104.bin
# 正在处理第104个文件
# K:/dataset/1000/5\105.bin
# 正在处理第105个文件
# K:/dataset/1000/5\106.bin
# 正在处理第106个文件
# K:/dataset/1000/5\107.bin
# 正在处理第107个文件
# K:/dataset/1000/5\108.bin
# 正在处理第108个文件
# K:/dataset/1000/5\109.bin
# 正在处理第109个文件
# K:/dataset/1000/5\110.bin
# 正在处理第110个文件
# K:/dataset/1000/5\111.bin
# 正在处理第111个文件
# K:/dataset/1000/5\112.bin
# 正在处理第112个文件
# K:/dataset/1000/5\113.bin
# 正在处理第113个文件
# K:/dataset/1000/5\114.bin
# 正在处理第114个文件
# K:/dataset/1000/5\115.bin
# 正在处理第115个文件
# K:/dataset/1000/5\116.bin
# 正在处理第116个文件
# K:/dataset/1000/5\117.bin
# 正在处理第117个文件
# K:/dataset/1000/5\118.bin
# 正在处理第118个文件
# K:/dataset/1000/5\119.bin
# 正在处理第119个文件
# K:/dataset/1000/5\120.bin
# 正在处理第120个文件
# K:/dataset/1000/5\121.bin
# 正在处理第121个文件
# K:/dataset/1000/5\122.bin
# 正在处理第122个文件
# K:/dataset/1000/5\123.bin
# 正在处理第123个文件
# K:/dataset/1000/5\124.bin
# 正在处理第124个文件
# K:/dataset/1000/5\125.bin
# 正在处理第125个文件
# K:/dataset/1000/5\126.bin
# 正在处理第126个文件
# K:/dataset/1000/5\127.bin
# 正在处理第127个文件
# K:/dataset/1000/5\128.bin
# 正在处理第128个文件
# K:/dataset/1000/5\129.bin
# 正在处理第129个文件
# K:/dataset/1000/5\130.bin
# 正在处理第130个文件
# K:/dataset/1000/5\131.bin
# 正在处理第131个文件
# K:/dataset/1000/5\132.bin
# 正在处理第132个文件
# K:/dataset/1000/5\133.bin
# 正在处理第133个文件
# K:/dataset/1000/5\134.bin
# 正在处理第134个文件
# K:/dataset/1000/5\135.bin
# 正在处理第135个文件
# K:/dataset/1000/5\136.bin
# 正在处理第136个文件
# K:/dataset/1000/5\137.bin
# 正在处理第137个文件
# K:/dataset/1000/5\138.bin
# 正在处理第138个文件
# K:/dataset/1000/5\139.bin
# 正在处理第139个文件
# K:/dataset/1000/5\140.bin
# 正在处理第140个文件
# K:/dataset/1000/5\141.bin
# 正在处理第141个文件
# K:/dataset/1000/5\142.bin
# 正在处理第142个文件
# K:/dataset/1000/5\143.bin
# 正在处理第143个文件
# K:/dataset/1000/5\144.bin
# 正在处理第144个文件
# K:/dataset/1000/5\145.bin
# 正在处理第145个文件
# K:/dataset/1000/5\146.bin
# 正在处理第146个文件
# K:/dataset/1000/5\147.bin
# 正在处理第147个文件
# K:/dataset/1000/5\148.bin
# 正在处理第148个文件
# K:/dataset/1000/5\149.bin
# 正在处理第149个文件
# K:/dataset/1000/5\150.bin
# 正在处理第150个文件
# K:/dataset/1000/5\151.bin
# 正在处理第151个文件
# K:/dataset/1000/5\152.bin
# 正在处理第152个文件
# K:/dataset/1000/5\153.bin
# 正在处理第153个文件
# K:/dataset/1000/5\154.bin
# 正在处理第154个文件
# K:/dataset/1000/5\155.bin
# 正在处理第155个文件
# K:/dataset/1000/5\156.bin
# 正在处理第156个文件
# K:/dataset/1000/5\157.bin
# 正在处理第157个文件
# K:/dataset/1000/5\158.bin
# 正在处理第158个文件
# K:/dataset/1000/5\159.bin
# 正在处理第159个文件
# K:/dataset/1000/5\160.bin
# 正在处理第160个文件
# K:/dataset/1000/5\161.bin
# 正在处理第161个文件
# K:/dataset/1000/5\162.bin
# 正在处理第162个文件
# K:/dataset/1000/5\163.bin
# 正在处理第163个文件
# K:/dataset/1000/5\164.bin
# 正在处理第164个文件
# K:/dataset/1000/5\165.bin
# 正在处理第165个文件
# K:/dataset/1000/5\166.bin
# 正在处理第166个文件
# K:/dataset/1000/5\167.bin
# 正在处理第167个文件
# K:/dataset/1000/5\168.bin
# 正在处理第168个文件
# K:/dataset/1000/5\169.bin
# 正在处理第169个文件
# K:/dataset/1000/5\170.bin
# 正在处理第170个文件
# K:/dataset/1000/5\171.bin
# 正在处理第171个文件
# K:/dataset/1000/5\172.bin
# 正在处理第172个文件
# K:/dataset/1000/5\173.bin
# 正在处理第173个文件
# K:/dataset/1000/5\174.bin
# 正在处理第174个文件
# K:/dataset/1000/5\175.bin
# 正在处理第175个文件
# K:/dataset/1000/5\176.bin
# 正在处理第176个文件
# K:/dataset/1000/5\177.bin
# 正在处理第177个文件
# K:/dataset/1000/5\178.bin
# 正在处理第178个文件
# K:/dataset/1000/5\179.bin
# 正在处理第179个文件
# K:/dataset/1000/5\180.bin
# 正在处理第180个文件
# K:/dataset/1000/5\181.bin
# 正在处理第181个文件
# K:/dataset/1000/5\182.bin
# 正在处理第182个文件
# K:/dataset/1000/5\183.bin
# 正在处理第183个文件
# K:/dataset/1000/5\184.bin
# 正在处理第184个文件
# K:/dataset/1000/5\185.bin
# 正在处理第185个文件
# K:/dataset/1000/5\186.bin
# 正在处理第186个文件
# K:/dataset/1000/5\187.bin
# 正在处理第187个文件
# K:/dataset/1000/5\188.bin
# 正在处理第188个文件
# K:/dataset/1000/5\189.bin
# 正在处理第189个文件
# K:/dataset/1000/5\190.bin
# 正在处理第190个文件
# K:/dataset/1000/5\191.bin
# 正在处理第191个文件
# K:/dataset/1000/5\192.bin
# 正在处理第192个文件
# K:/dataset/1000/5\193.bin
# 正在处理第193个文件
# K:/dataset/1000/5\194.bin
# 正在处理第194个文件
# K:/dataset/1000/5\195.bin
# 正在处理第195个文件
# K:/dataset/1000/5\196.bin
# 正在处理第196个文件
# K:/dataset/1000/5\197.bin
# 正在处理第197个文件
# K:/dataset/1000/5\198.bin
# 正在处理第198个文件
# K:/dataset/1000/5\199.bin
# 正在处理第199个文件
# K:/dataset/1000/5\200.bin
# 正在处理第200个文件
# K:/dataset/1000/5\201.bin
# 正在处理第201个文件
# K:/dataset/1000/5\202.bin
# 正在处理第202个文件
# K:/dataset/1000/5\203.bin
# 正在处理第203个文件
# K:/dataset/1000/5\204.bin
# 正在处理第204个文件
# K:/dataset/1000/5\205.bin
# 正在处理第205个文件
# K:/dataset/1000/5\206.bin
# 正在处理第206个文件
# K:/dataset/1000/5\207.bin
# 正在处理第207个文件
# K:/dataset/1000/5\208.bin
# 正在处理第208个文件
# K:/dataset/1000/5\209.bin
# 正在处理第209个文件
# K:/dataset/1000/5\210.bin
# 正在处理第210个文件
# K:/dataset/1000/5\211.bin
# 正在处理第211个文件
# K:/dataset/1000/5\212.bin
# 正在处理第212个文件
# K:/dataset/1000/5\213.bin
# 正在处理第213个文件
# K:/dataset/1000/5\214.bin
# 正在处理第214个文件
# K:/dataset/1000/5\215.bin
# 正在处理第215个文件
# K:/dataset/1000/5\216.bin
# 正在处理第216个文件
# K:/dataset/1000/5\217.bin
# 正在处理第217个文件
# K:/dataset/1000/5\218.bin
# 正在处理第218个文件
# K:/dataset/1000/5\219.bin
# 正在处理第219个文件
# K:/dataset/1000/5\220.bin
# 正在处理第220个文件
# K:/dataset/1000/5\221.bin
# 正在处理第221个文件
# K:/dataset/1000/5\222.bin
# 正在处理第222个文件
# K:/dataset/1000/5\223.bin
# 正在处理第223个文件
# K:/dataset/1000/5\224.bin
# 正在处理第224个文件
# K:/dataset/1000/5\225.bin
# 正在处理第225个文件
# K:/dataset/1000/5\226.bin
# 正在处理第226个文件
# K:/dataset/1000/5\227.bin
# 正在处理第227个文件
# K:/dataset/1000/5\228.bin
# 正在处理第228个文件
# K:/dataset/1000/5\229.bin
# 正在处理第229个文件
# K:/dataset/1000/5\230.bin
# 正在处理第230个文件
# K:/dataset/1000/5\231.bin
# 正在处理第231个文件
# K:/dataset/1000/5\232.bin
# 正在处理第232个文件
# K:/dataset/1000/5\233.bin
# 正在处理第233个文件
# K:/dataset/1000/5\234.bin
# 正在处理第234个文件
# K:/dataset/1000/5\235.bin
# 正在处理第235个文件
# K:/dataset/1000/5\236.bin
# 正在处理第236个文件
# K:/dataset/1000/5\237.bin
# 正在处理第237个文件
# K:/dataset/1000/5\238.bin
# 正在处理第238个文件
# K:/dataset/1000/5\239.bin
# 正在处理第239个文件
# K:/dataset/1000/5\240.bin
# 正在处理第240个文件
# K:/dataset/1000/5\241.bin
# 正在处理第241个文件
# K:/dataset/1000/5\242.bin
# 正在处理第242个文件
# K:/dataset/1000/5\243.bin
# 正在处理第243个文件
# K:/dataset/1000/5\244.bin
# 正在处理第244个文件
# K:/dataset/1000/5\245.bin
# 正在处理第245个文件
# K:/dataset/1000/5\246.bin
# 正在处理第246个文件
# K:/dataset/1000/5\247.bin
# 正在处理第247个文件
# K:/dataset/1000/5\248.bin
# 正在处理第248个文件
# K:/dataset/1000/5\249.bin
# 正在处理第249个文件
# K:/dataset/1000/5\250.bin
# 正在处理第250个文件
# K:/dataset/1000/5\251.bin
# 正在处理第251个文件
# K:/dataset/1000/5\252.bin
# 正在处理第252个文件
# K:/dataset/1000/5\253.bin
# 正在处理第253个文件
# K:/dataset/1000/5\254.bin
# 正在处理第254个文件
# K:/dataset/1000/5\255.bin
# 正在处理第255个文件
# K:/dataset/1000/5\256.bin
# 正在处理第256个文件
# K:/dataset/1000/5\257.bin
# 正在处理第257个文件
# K:/dataset/1000/5\258.bin
# 正在处理第258个文件
# K:/dataset/1000/5\259.bin
# 正在处理第259个文件
# K:/dataset/1000/5\260.bin
# 正在处理第260个文件
# K:/dataset/1000/5\261.bin
# 正在处理第261个文件
# K:/dataset/1000/5\262.bin
# 正在处理第262个文件
# K:/dataset/1000/5\263.bin
# 正在处理第263个文件
# K:/dataset/1000/5\264.bin
# 正在处理第264个文件
# K:/dataset/1000/5\265.bin
# 正在处理第265个文件
# K:/dataset/1000/5\266.bin
# 正在处理第266个文件
# K:/dataset/1000/5\267.bin
# 正在处理第267个文件
# K:/dataset/1000/5\268.bin
# 正在处理第268个文件
# K:/dataset/1000/5\269.bin
# 正在处理第269个文件
# K:/dataset/1000/5\270.bin
# 正在处理第270个文件
# K:/dataset/1000/5\271.bin
# 正在处理第271个文件
# K:/dataset/1000/5\272.bin
# 正在处理第272个文件
# K:/dataset/1000/5\273.bin
# 正在处理第273个文件
# K:/dataset/1000/5\274.bin
# 正在处理第274个文件
# K:/dataset/1000/5\275.bin
# 正在处理第275个文件
# K:/dataset/1000/5\276.bin
# 正在处理第276个文件
# K:/dataset/1000/5\277.bin
# 正在处理第277个文件
# K:/dataset/1000/5\278.bin
# 正在处理第278个文件
# K:/dataset/1000/5\279.bin
# 正在处理第279个文件
# K:/dataset/1000/5\280.bin
# 正在处理第280个文件
# K:/dataset/1000/5\281.bin
# 正在处理第281个文件
# K:/dataset/1000/5\282.bin
# 正在处理第282个文件
# K:/dataset/1000/5\283.bin
# 正在处理第283个文件
# K:/dataset/1000/5\284.bin
# 正在处理第284个文件
# K:/dataset/1000/5\285.bin
# 正在处理第285个文件
# K:/dataset/1000/5\286.bin
# 正在处理第286个文件
# K:/dataset/1000/5\287.bin
# 正在处理第287个文件
# K:/dataset/1000/5\288.bin
# 正在处理第288个文件
# K:/dataset/1000/5\289.bin
# 正在处理第289个文件
# K:/dataset/1000/5\290.bin
# 正在处理第290个文件
# K:/dataset/1000/5\291.bin
# 正在处理第291个文件
# K:/dataset/1000/5\292.bin
# 正在处理第292个文件
# K:/dataset/1000/5\293.bin
# 正在处理第293个文件
# K:/dataset/1000/5\294.bin
# 正在处理第294个文件
# K:/dataset/1000/5\295.bin
# 正在处理第295个文件
# K:/dataset/1000/5\296.bin
# 正在处理第296个文件
# K:/dataset/1000/5\297.bin
# 正在处理第297个文件
# K:/dataset/1000/5\298.bin
# 正在处理第298个文件
# K:/dataset/1000/5\299.bin
# 正在处理第299个文件
# K:/dataset/1000/5\300.bin
# 正在处理第300个文件
# K:/dataset/1000/5\301.bin
# 正在处理第301个文件
# K:/dataset/1000/5\302.bin
# 正在处理第302个文件
# K:/dataset/1000/5\303.bin
# 正在处理第303个文件
# K:/dataset/1000/5\304.bin
# 正在处理第304个文件
# K:/dataset/1000/5\305.bin
# 正在处理第305个文件
# K:/dataset/1000/5\306.bin
# 正在处理第306个文件
# K:/dataset/1000/5\307.bin
# 正在处理第307个文件
# K:/dataset/1000/5\308.bin
# 正在处理第308个文件
# K:/dataset/1000/5\309.bin
# 正在处理第309个文件
# K:/dataset/1000/5\310.bin
# 正在处理第310个文件
# K:/dataset/1000/5\311.bin
# 正在处理第311个文件
# K:/dataset/1000/5\312.bin
# 正在处理第312个文件
# K:/dataset/1000/5\313.bin
# 正在处理第313个文件
# K:/dataset/1000/5\314.bin
# 正在处理第314个文件
# K:/dataset/1000/5\315.bin
# 正在处理第315个文件
# K:/dataset/1000/5\316.bin
# 正在处理第316个文件
# K:/dataset/1000/5\317.bin
# 正在处理第317个文件
# K:/dataset/1000/5\318.bin
# 正在处理第318个文件
# K:/dataset/1000/5\319.bin
# 正在处理第319个文件
# K:/dataset/1000/5\320.bin
# 正在处理第320个文件
# K:/dataset/1000/5\321.bin
# 正在处理第321个文件
# K:/dataset/1000/5\322.bin
# 正在处理第322个文件
# K:/dataset/1000/5\323.bin
# 正在处理第323个文件
# K:/dataset/1000/5\324.bin
# 正在处理第324个文件
# K:/dataset/1000/5\325.bin
# 正在处理第325个文件
# K:/dataset/1000/5\326.bin
# 正在处理第326个文件
# K:/dataset/1000/5\327.bin
# 正在处理第327个文件
# K:/dataset/1000/5\328.bin
# 正在处理第328个文件
# K:/dataset/1000/5\329.bin
# 正在处理第329个文件
# K:/dataset/1000/5\330.bin
# 正在处理第330个文件
# K:/dataset/1000/5\331.bin
# 正在处理第331个文件
# K:/dataset/1000/5\332.bin
# 正在处理第332个文件
# K:/dataset/1000/5\333.bin
# 正在处理第333个文件
# K:/dataset/1000/5\334.bin
# 正在处理第334个文件
# K:/dataset/1000/5\335.bin
# 正在处理第335个文件
# K:/dataset/1000/5\336.bin
# 正在处理第336个文件
# K:/dataset/1000/5\337.bin
# 正在处理第337个文件
# K:/dataset/1000/5\338.bin
# 正在处理第338个文件
# K:/dataset/1000/5\339.bin
# 正在处理第339个文件
# K:/dataset/1000/5\340.bin
# 正在处理第340个文件
# K:/dataset/1000/5\341.bin
# 正在处理第341个文件
# K:/dataset/1000/5\342.bin
# 正在处理第342个文件
# K:/dataset/1000/5\343.bin
# 正在处理第343个文件
# K:/dataset/1000/5\344.bin
# 正在处理第344个文件
# K:/dataset/1000/5\345.bin
# 正在处理第345个文件
# K:/dataset/1000/5\346.bin
# 正在处理第346个文件
# K:/dataset/1000/5\347.bin
# 正在处理第347个文件
# K:/dataset/1000/5\348.bin
# 正在处理第348个文件
# K:/dataset/1000/5\349.bin
# 正在处理第349个文件
# K:/dataset/1000/5\350.bin
# 正在处理第350个文件
# K:/dataset/1000/5\351.bin
# 正在处理第351个文件
# K:/dataset/1000/5\352.bin
# 正在处理第352个文件
# K:/dataset/1000/5\353.bin
# 正在处理第353个文件
# K:/dataset/1000/5\354.bin
# 正在处理第354个文件
# K:/dataset/1000/5\355.bin
# 正在处理第355个文件
# K:/dataset/1000/5\356.bin
# 正在处理第356个文件
# K:/dataset/1000/5\357.bin
# 正在处理第357个文件
# K:/dataset/1000/5\358.bin
# 正在处理第358个文件
# K:/dataset/1000/5\359.bin
# 正在处理第359个文件
# K:/dataset/1000/5\360.bin
# 正在处理第360个文件
# K:/dataset/1000/5\361.bin
# 正在处理第361个文件
# K:/dataset/1000/5\362.bin
# 正在处理第362个文件
# K:/dataset/1000/5\363.bin
# 正在处理第363个文件
# K:/dataset/1000/5\364.bin
# 正在处理第364个文件
# K:/dataset/1000/5\365.bin
# 正在处理第365个文件
# K:/dataset/1000/5\366.bin
# 正在处理第366个文件
# K:/dataset/1000/5\367.bin
# 正在处理第367个文件
# K:/dataset/1000/5\368.bin
# 正在处理第368个文件
# K:/dataset/1000/5\369.bin
# 正在处理第369个文件
# K:/dataset/1000/5\370.bin
# 正在处理第370个文件
# K:/dataset/1000/5\371.bin
# 正在处理第371个文件
# K:/dataset/1000/5\372.bin
# 正在处理第372个文件
# K:/dataset/1000/5\373.bin
# 正在处理第373个文件
# K:/dataset/1000/5\374.bin
# 正在处理第374个文件
# K:/dataset/1000/5\375.bin
# 正在处理第375个文件
# K:/dataset/1000/5\376.bin
# 正在处理第376个文件
# K:/dataset/1000/5\377.bin
# 正在处理第377个文件
# K:/dataset/1000/5\378.bin
# 正在处理第378个文件
# K:/dataset/1000/5\379.bin
# 正在处理第379个文件
# K:/dataset/1000/5\380.bin
# 正在处理第380个文件
# K:/dataset/1000/5\381.bin
# 正在处理第381个文件
# K:/dataset/1000/5\382.bin
# 正在处理第382个文件
# K:/dataset/1000/5\383.bin
# 正在处理第383个文件
# K:/dataset/1000/5\384.bin
# 正在处理第384个文件
# K:/dataset/1000/5\385.bin
# 正在处理第385个文件
# K:/dataset/1000/5\386.bin
# 正在处理第386个文件
# K:/dataset/1000/5\387.bin
# 正在处理第387个文件
# K:/dataset/1000/5\388.bin
# 正在处理第388个文件
# K:/dataset/1000/5\389.bin
# 正在处理第389个文件
# K:/dataset/1000/5\390.bin
# 正在处理第390个文件
# K:/dataset/1000/5\391.bin
# 正在处理第391个文件
# K:/dataset/1000/5\392.bin
# 正在处理第392个文件
# K:/dataset/1000/5\393.bin
# 正在处理第393个文件
# K:/dataset/1000/5\394.bin
# 正在处理第394个文件
# K:/dataset/1000/5\395.bin
# 正在处理第395个文件
# K:/dataset/1000/5\396.bin
# 正在处理第396个文件
# K:/dataset/1000/5\397.bin
# 正在处理第397个文件
# K:/dataset/1000/5\398.bin
# 正在处理第398个文件
# K:/dataset/1000/5\399.bin
# 正在处理第399个文件
# K:/dataset/1000/5\400.bin
# 正在处理第400个文件
# K:/dataset/1000/5\401.bin
# 正在处理第401个文件
# K:/dataset/1000/5\402.bin
# 正在处理第402个文件
# K:/dataset/1000/5\403.bin
# 正在处理第403个文件
# K:/dataset/1000/5\404.bin
# 正在处理第404个文件
# K:/dataset/1000/5\405.bin
# 正在处理第405个文件
# K:/dataset/1000/5\406.bin
# 正在处理第406个文件
# K:/dataset/1000/5\407.bin
# 正在处理第407个文件
# K:/dataset/1000/5\408.bin
# 正在处理第408个文件
# K:/dataset/1000/5\409.bin
# 正在处理第409个文件
# K:/dataset/1000/5\410.bin
# 正在处理第410个文件
# K:/dataset/1000/5\411.bin
# 正在处理第411个文件
# K:/dataset/1000/5\412.bin
# 正在处理第412个文件
# K:/dataset/1000/5\413.bin
# 正在处理第413个文件
# K:/dataset/1000/5\414.bin
# 正在处理第414个文件
# K:/dataset/1000/5\415.bin
# 正在处理第415个文件
# K:/dataset/1000/5\416.bin
# 正在处理第416个文件
# K:/dataset/1000/5\417.bin
# 正在处理第417个文件
# K:/dataset/1000/5\418.bin
# 正在处理第418个文件
# K:/dataset/1000/5\419.bin
# 正在处理第419个文件
# K:/dataset/1000/5\420.bin
# 正在处理第420个文件
# K:/dataset/1000/5\421.bin
# 正在处理第421个文件
# K:/dataset/1000/5\422.bin
# 正在处理第422个文件
# K:/dataset/1000/5\423.bin
# 正在处理第423个文件
# K:/dataset/1000/5\424.bin
# 正在处理第424个文件
# K:/dataset/1000/5\425.bin
# 正在处理第425个文件
# K:/dataset/1000/5\426.bin
# 正在处理第426个文件
# K:/dataset/1000/5\427.bin
# 正在处理第427个文件
# K:/dataset/1000/5\428.bin
# 正在处理第428个文件
# K:/dataset/1000/5\429.bin
# 正在处理第429个文件
# K:/dataset/1000/5\430.bin
# 正在处理第430个文件
# K:/dataset/1000/5\431.bin
# 正在处理第431个文件
# K:/dataset/1000/5\432.bin
# 正在处理第432个文件
# K:/dataset/1000/5\433.bin
# 正在处理第433个文件
# K:/dataset/1000/5\434.bin
# 正在处理第434个文件
# K:/dataset/1000/5\435.bin
# 正在处理第435个文件
# K:/dataset/1000/5\436.bin
# 正在处理第436个文件
# K:/dataset/1000/5\437.bin
# 正在处理第437个文件
# K:/dataset/1000/5\438.bin
# 正在处理第438个文件
# K:/dataset/1000/5\439.bin
# 正在处理第439个文件
# K:/dataset/1000/5\440.bin
# 正在处理第440个文件
# K:/dataset/1000/5\441.bin
# 正在处理第441个文件
# K:/dataset/1000/5\442.bin
# 正在处理第442个文件
# K:/dataset/1000/5\443.bin
# 正在处理第443个文件
# K:/dataset/1000/5\444.bin
# 正在处理第444个文件
# K:/dataset/1000/5\445.bin
# 正在处理第445个文件
# K:/dataset/1000/5\446.bin
# 正在处理第446个文件
# K:/dataset/1000/5\447.bin
# 正在处理第447个文件
# K:/dataset/1000/5\448.bin
# 正在处理第448个文件
# K:/dataset/1000/5\449.bin
# 正在处理第449个文件
# K:/dataset/1000/5\450.bin
# 正在处理第450个文件
# K:/dataset/1000/5\451.bin
# 正在处理第451个文件
# K:/dataset/1000/5\452.bin
# 正在处理第452个文件
# K:/dataset/1000/5\453.bin
# 正在处理第453个文件
# K:/dataset/1000/5\454.bin
# 正在处理第454个文件
# K:/dataset/1000/5\455.bin
# 正在处理第455个文件
# K:/dataset/1000/5\456.bin
# 正在处理第456个文件
# K:/dataset/1000/5\457.bin
# 正在处理第457个文件
# K:/dataset/1000/5\458.bin
# 正在处理第458个文件
# K:/dataset/1000/5\459.bin
# 正在处理第459个文件
# K:/dataset/1000/5\460.bin
# 正在处理第460个文件
# K:/dataset/1000/5\461.bin
# 正在处理第461个文件
# K:/dataset/1000/5\462.bin
# 正在处理第462个文件
# K:/dataset/1000/5\463.bin
# 正在处理第463个文件
# K:/dataset/1000/5\464.bin
# 正在处理第464个文件
# K:/dataset/1000/5\465.bin
# 正在处理第465个文件
# K:/dataset/1000/5\466.bin
# 正在处理第466个文件
# K:/dataset/1000/5\467.bin
# 正在处理第467个文件
# K:/dataset/1000/5\468.bin
# 正在处理第468个文件
# K:/dataset/1000/5\469.bin
# 正在处理第469个文件
# K:/dataset/1000/5\470.bin
# 正在处理第470个文件
# K:/dataset/1000/5\471.bin
# 正在处理第471个文件
# K:/dataset/1000/5\472.bin
# 正在处理第472个文件
# K:/dataset/1000/5\473.bin
# 正在处理第473个文件
# K:/dataset/1000/5\474.bin
# 正在处理第474个文件
# K:/dataset/1000/5\475.bin
# 正在处理第475个文件
# K:/dataset/1000/5\476.bin
# 正在处理第476个文件
# K:/dataset/1000/5\477.bin
# 正在处理第477个文件
# K:/dataset/1000/5\478.bin
# 正在处理第478个文件
# K:/dataset/1000/5\479.bin
# 正在处理第479个文件
# K:/dataset/1000/5\480.bin
# 正在处理第480个文件
# K:/dataset/1000/5\481.bin
# 正在处理第481个文件
# K:/dataset/1000/5\482.bin
# 正在处理第482个文件
# K:/dataset/1000/5\483.bin
# 正在处理第483个文件
# K:/dataset/1000/5\484.bin
# 正在处理第484个文件
# K:/dataset/1000/5\485.bin
# 正在处理第485个文件
# K:/dataset/1000/5\486.bin
# 正在处理第486个文件
# K:/dataset/1000/5\487.bin
# 正在处理第487个文件
# K:/dataset/1000/5\488.bin
# 正在处理第488个文件
# K:/dataset/1000/5\489.bin
# 正在处理第489个文件
# K:/dataset/1000/5\490.bin
# 正在处理第490个文件
# K:/dataset/1000/5\491.bin
# 正在处理第491个文件
# K:/dataset/1000/5\492.bin
# 正在处理第492个文件
# K:/dataset/1000/5\493.bin
# 正在处理第493个文件
# K:/dataset/1000/5\494.bin
# 正在处理第494个文件
# K:/dataset/1000/5\495.bin
# 正在处理第495个文件
# K:/dataset/1000/5\496.bin
# 正在处理第496个文件
# K:/dataset/1000/5\497.bin
# 正在处理第497个文件
# K:/dataset/1000/5\498.bin
# 正在处理第498个文件
# K:/dataset/1000/5\499.bin
# 正在处理第499个文件
# K:/dataset/1000/5\500.bin
# 正在处理第500个文件
# K:/dataset/1000/5\501.bin
# 正在处理第501个文件
# K:/dataset/1000/5\502.bin
# 正在处理第502个文件
# K:/dataset/1000/5\503.bin
# 正在处理第503个文件
# K:/dataset/1000/5\504.bin
# 正在处理第504个文件
# K:/dataset/1000/5\505.bin
# 正在处理第505个文件
# K:/dataset/1000/5\506.bin
# 正在处理第506个文件
# K:/dataset/1000/5\507.bin
# 正在处理第507个文件
# K:/dataset/1000/5\508.bin
# 正在处理第508个文件
# K:/dataset/1000/5\509.bin
# 正在处理第509个文件
# K:/dataset/1000/5\510.bin
# 正在处理第510个文件
# K:/dataset/1000/5\511.bin
# 正在处理第511个文件
# K:/dataset/1000/5\512.bin
# 正在处理第512个文件
# K:/dataset/1000/5\513.bin
# 正在处理第513个文件
# K:/dataset/1000/5\514.bin
# 正在处理第514个文件
# K:/dataset/1000/5\515.bin
# 正在处理第515个文件
# K:/dataset/1000/5\516.bin
# 正在处理第516个文件
# K:/dataset/1000/5\517.bin
# 正在处理第517个文件
# K:/dataset/1000/5\518.bin
# 正在处理第518个文件
# K:/dataset/1000/5\519.bin
# 正在处理第519个文件
# K:/dataset/1000/5\520.bin
# 正在处理第520个文件
# K:/dataset/1000/5\521.bin
# 正在处理第521个文件
# K:/dataset/1000/5\522.bin
# 正在处理第522个文件
# K:/dataset/1000/5\523.bin
# 正在处理第523个文件
# K:/dataset/1000/5\524.bin
# 正在处理第524个文件
# K:/dataset/1000/5\525.bin
# 正在处理第525个文件
# K:/dataset/1000/5\526.bin
# 正在处理第526个文件
# K:/dataset/1000/5\527.bin
# 正在处理第527个文件
# K:/dataset/1000/5\528.bin
# 正在处理第528个文件
# K:/dataset/1000/5\529.bin
# 正在处理第529个文件
# K:/dataset/1000/5\530.bin
# 正在处理第530个文件
# K:/dataset/1000/5\531.bin
# 正在处理第531个文件
# K:/dataset/1000/5\532.bin
# 正在处理第532个文件
# K:/dataset/1000/5\533.bin
# 正在处理第533个文件
# K:/dataset/1000/5\534.bin
# 正在处理第534个文件
# K:/dataset/1000/5\535.bin
# 正在处理第535个文件
# K:/dataset/1000/5\536.bin
# 正在处理第536个文件
# K:/dataset/1000/5\537.bin
# 正在处理第537个文件
# K:/dataset/1000/5\538.bin
# 正在处理第538个文件
# K:/dataset/1000/5\539.bin
# 正在处理第539个文件
# K:/dataset/1000/5\540.bin
# 正在处理第540个文件
# K:/dataset/1000/5\541.bin
# 正在处理第541个文件
# K:/dataset/1000/5\542.bin
# 正在处理第542个文件
# K:/dataset/1000/5\543.bin
# 正在处理第543个文件
# K:/dataset/1000/5\544.bin
# 正在处理第544个文件
# K:/dataset/1000/5\545.bin
# 正在处理第545个文件
# K:/dataset/1000/5\546.bin
# 正在处理第546个文件
# K:/dataset/1000/5\547.bin
# 正在处理第547个文件
# K:/dataset/1000/5\548.bin
# 正在处理第548个文件
# K:/dataset/1000/5\549.bin
# 正在处理第549个文件
# K:/dataset/1000/5\550.bin
# 正在处理第550个文件
# K:/dataset/1000/5\551.bin
# 正在处理第551个文件
# K:/dataset/1000/5\552.bin
# 正在处理第552个文件
# K:/dataset/1000/5\553.bin
# 正在处理第553个文件
# K:/dataset/1000/5\554.bin
# 正在处理第554个文件
# K:/dataset/1000/5\555.bin
# 正在处理第555个文件
# K:/dataset/1000/5\556.bin
# 正在处理第556个文件
# K:/dataset/1000/5\557.bin
# 正在处理第557个文件
# K:/dataset/1000/5\558.bin
# 正在处理第558个文件
# K:/dataset/1000/5\559.bin
# 正在处理第559个文件
# K:/dataset/1000/5\560.bin
# 正在处理第560个文件
# K:/dataset/1000/5\561.bin
# 正在处理第561个文件
# K:/dataset/1000/5\562.bin
# 正在处理第562个文件
# K:/dataset/1000/5\563.bin
# 正在处理第563个文件
# K:/dataset/1000/5\564.bin
# 正在处理第564个文件
# K:/dataset/1000/5\565.bin
# 正在处理第565个文件
# K:/dataset/1000/5\566.bin
# 正在处理第566个文件
# K:/dataset/1000/5\567.bin
# 正在处理第567个文件
# K:/dataset/1000/5\568.bin
# 正在处理第568个文件
# K:/dataset/1000/5\569.bin
# 正在处理第569个文件
# K:/dataset/1000/5\570.bin
# 正在处理第570个文件
# K:/dataset/1000/5\571.bin
# 正在处理第571个文件
# K:/dataset/1000/5\572.bin
# 正在处理第572个文件
# K:/dataset/1000/5\573.bin
# 正在处理第573个文件
# K:/dataset/1000/5\574.bin
# 正在处理第574个文件
# K:/dataset/1000/5\575.bin
# 正在处理第575个文件
# K:/dataset/1000/5\576.bin
# 正在处理第576个文件
# K:/dataset/1000/5\577.bin
# 正在处理第577个文件
# K:/dataset/1000/5\578.bin
# 正在处理第578个文件
# K:/dataset/1000/5\579.bin
# 正在处理第579个文件
# K:/dataset/1000/5\580.bin
# 正在处理第580个文件
# K:/dataset/1000/5\581.bin
# 正在处理第581个文件
# K:/dataset/1000/5\582.bin
# 正在处理第582个文件
# K:/dataset/1000/5\583.bin
# 正在处理第583个文件
# K:/dataset/1000/5\584.bin
# 正在处理第584个文件
# K:/dataset/1000/5\585.bin
# 正在处理第585个文件
# K:/dataset/1000/5\586.bin
# 正在处理第586个文件
# K:/dataset/1000/5\587.bin
# 正在处理第587个文件
# K:/dataset/1000/5\588.bin
# 正在处理第588个文件
# K:/dataset/1000/5\589.bin
# 正在处理第589个文件
# K:/dataset/1000/5\590.bin
# 正在处理第590个文件
# K:/dataset/1000/5\591.bin
# 正在处理第591个文件
# K:/dataset/1000/5\592.bin
# 正在处理第592个文件
# K:/dataset/1000/5\593.bin
# 正在处理第593个文件
# K:/dataset/1000/5\594.bin
# 正在处理第594个文件
# K:/dataset/1000/5\595.bin
# 正在处理第595个文件
# K:/dataset/1000/5\596.bin
# 正在处理第596个文件
# K:/dataset/1000/5\597.bin
# 正在处理第597个文件
# K:/dataset/1000/5\598.bin
# 正在处理第598个文件
# K:/dataset/1000/5\599.bin
# 正在处理第599个文件
# K:/dataset/1000/5\600.bin
# 正在处理第600个文件
# K:/dataset/1000/5\601.bin
# 正在处理第601个文件
# K:/dataset/1000/5\602.bin
# 正在处理第602个文件
# K:/dataset/1000/5\603.bin
# 正在处理第603个文件
# K:/dataset/1000/5\604.bin
# 正在处理第604个文件
# K:/dataset/1000/5\605.bin
# 正在处理第605个文件
# K:/dataset/1000/5\606.bin
# 正在处理第606个文件
# K:/dataset/1000/5\607.bin
# 正在处理第607个文件
# K:/dataset/1000/5\608.bin
# 正在处理第608个文件
# K:/dataset/1000/5\609.bin
# 正在处理第609个文件
# K:/dataset/1000/5\610.bin
# 正在处理第610个文件
# K:/dataset/1000/5\611.bin
# 正在处理第611个文件
# K:/dataset/1000/5\612.bin
# 正在处理第612个文件
# K:/dataset/1000/5\613.bin
# 正在处理第613个文件
# K:/dataset/1000/5\614.bin
# 正在处理第614个文件
# K:/dataset/1000/5\615.bin
# 正在处理第615个文件
# K:/dataset/1000/5\616.bin
# 正在处理第616个文件
# K:/dataset/1000/5\617.bin
# 正在处理第617个文件
# K:/dataset/1000/5\618.bin
# 正在处理第618个文件
# K:/dataset/1000/5\619.bin
# 正在处理第619个文件
# K:/dataset/1000/5\620.bin
# 正在处理第620个文件
# K:/dataset/1000/5\621.bin
# 正在处理第621个文件
# K:/dataset/1000/5\622.bin
# 正在处理第622个文件
# K:/dataset/1000/5\623.bin
# 正在处理第623个文件
# K:/dataset/1000/5\624.bin
# 正在处理第624个文件
# K:/dataset/1000/5\625.bin
# 正在处理第625个文件
# K:/dataset/1000/5\626.bin
# 正在处理第626个文件
# K:/dataset/1000/5\627.bin
# 正在处理第627个文件
# K:/dataset/1000/5\628.bin
# 正在处理第628个文件
# K:/dataset/1000/5\629.bin
# 正在处理第629个文件
# K:/dataset/1000/5\630.bin
# 正在处理第630个文件
# K:/dataset/1000/5\631.bin
# 正在处理第631个文件
# K:/dataset/1000/5\632.bin
# 正在处理第632个文件
# K:/dataset/1000/5\633.bin
# 正在处理第633个文件
# K:/dataset/1000/5\634.bin
# 正在处理第634个文件
# K:/dataset/1000/5\635.bin
# 正在处理第635个文件
# K:/dataset/1000/5\636.bin
# 正在处理第636个文件
# K:/dataset/1000/5\637.bin
# 正在处理第637个文件
# K:/dataset/1000/5\638.bin
# 正在处理第638个文件
# K:/dataset/1000/5\639.bin
# 正在处理第639个文件
# K:/dataset/1000/5\640.bin
# 正在处理第640个文件
# K:/dataset/1000/5\641.bin
# 正在处理第641个文件
# K:/dataset/1000/5\642.bin
# 正在处理第642个文件
# K:/dataset/1000/5\643.bin
# 正在处理第643个文件
# K:/dataset/1000/5\644.bin
# 正在处理第644个文件
# K:/dataset/1000/5\645.bin
# 正在处理第645个文件
# K:/dataset/1000/5\646.bin
# 正在处理第646个文件
# K:/dataset/1000/5\647.bin
# 正在处理第647个文件
# K:/dataset/1000/5\648.bin
# 正在处理第648个文件
# K:/dataset/1000/5\649.bin
# 正在处理第649个文件
# K:/dataset/1000/5\650.bin
# 正在处理第650个文件
# K:/dataset/1000/5\651.bin
# 正在处理第651个文件
# K:/dataset/1000/5\652.bin
# 正在处理第652个文件
# K:/dataset/1000/5\653.bin
# 正在处理第653个文件
# K:/dataset/1000/5\654.bin
# 正在处理第654个文件
# K:/dataset/1000/5\655.bin
# 正在处理第655个文件
# K:/dataset/1000/5\656.bin
# 正在处理第656个文件
# K:/dataset/1000/5\657.bin
# 正在处理第657个文件
# K:/dataset/1000/5\658.bin
# 正在处理第658个文件
# K:/dataset/1000/5\659.bin
# 正在处理第659个文件
# K:/dataset/1000/5\660.bin
# 正在处理第660个文件
# K:/dataset/1000/5\661.bin
# 正在处理第661个文件
# K:/dataset/1000/5\662.bin
# 正在处理第662个文件
# K:/dataset/1000/5\663.bin
# 正在处理第663个文件
# K:/dataset/1000/5\664.bin
# 正在处理第664个文件
# K:/dataset/1000/5\665.bin
# 正在处理第665个文件
# K:/dataset/1000/5\666.bin
# 正在处理第666个文件
# K:/dataset/1000/5\667.bin
# 正在处理第667个文件
# K:/dataset/1000/5\668.bin
# 正在处理第668个文件
# K:/dataset/1000/5\669.bin
# 正在处理第669个文件
# K:/dataset/1000/5\670.bin
# 正在处理第670个文件
# K:/dataset/1000/5\671.bin
# 正在处理第671个文件
# K:/dataset/1000/5\672.bin
# 正在处理第672个文件
# K:/dataset/1000/5\673.bin
# 正在处理第673个文件
# K:/dataset/1000/5\674.bin
# 正在处理第674个文件
# K:/dataset/1000/5\675.bin
# 正在处理第675个文件
# K:/dataset/1000/5\676.bin
# 正在处理第676个文件
# K:/dataset/1000/5\677.bin
# 正在处理第677个文件
# K:/dataset/1000/5\678.bin
# 正在处理第678个文件
# K:/dataset/1000/5\679.bin
# 正在处理第679个文件
# K:/dataset/1000/5\680.bin
# 正在处理第680个文件
# K:/dataset/1000/5\681.bin
# 正在处理第681个文件
# K:/dataset/1000/5\682.bin
# 正在处理第682个文件
# K:/dataset/1000/5\683.bin
# 正在处理第683个文件
# K:/dataset/1000/5\684.bin
# 正在处理第684个文件
# K:/dataset/1000/5\685.bin
# 正在处理第685个文件
# K:/dataset/1000/5\686.bin
# 正在处理第686个文件
# K:/dataset/1000/5\687.bin
# 正在处理第687个文件
# K:/dataset/1000/5\688.bin
# 正在处理第688个文件
# K:/dataset/1000/5\689.bin
# 正在处理第689个文件
# K:/dataset/1000/5\690.bin
# 正在处理第690个文件
# K:/dataset/1000/5\691.bin
# 正在处理第691个文件
# K:/dataset/1000/5\692.bin
# 正在处理第692个文件
# K:/dataset/1000/5\693.bin
# 正在处理第693个文件
# K:/dataset/1000/5\694.bin
# 正在处理第694个文件
# K:/dataset/1000/5\695.bin
# 正在处理第695个文件
# K:/dataset/1000/5\696.bin
# 正在处理第696个文件
# K:/dataset/1000/5\697.bin
# 正在处理第697个文件
# K:/dataset/1000/5\698.bin
# 正在处理第698个文件
# K:/dataset/1000/5\699.bin
# 正在处理第699个文件
# K:/dataset/1000/5\700.bin
# 正在处理第700个文件
# K:/dataset/1000/5\701.bin
# 正在处理第701个文件
# K:/dataset/1000/5\702.bin
# 正在处理第702个文件
# K:/dataset/1000/5\703.bin
# 正在处理第703个文件
# K:/dataset/1000/5\704.bin
# 正在处理第704个文件
# K:/dataset/1000/5\705.bin
# 正在处理第705个文件
# K:/dataset/1000/5\706.bin
# 正在处理第706个文件
# K:/dataset/1000/5\707.bin
# 正在处理第707个文件
# K:/dataset/1000/5\708.bin
# 正在处理第708个文件
# K:/dataset/1000/5\709.bin
# 正在处理第709个文件
# K:/dataset/1000/5\710.bin
# 正在处理第710个文件
# K:/dataset/1000/5\711.bin
# 正在处理第711个文件
# K:/dataset/1000/5\712.bin
# 正在处理第712个文件
# K:/dataset/1000/5\713.bin
# 正在处理第713个文件
# K:/dataset/1000/5\714.bin
# 正在处理第714个文件
# K:/dataset/1000/5\715.bin
# 正在处理第715个文件
# K:/dataset/1000/5\716.bin
# 正在处理第716个文件
# K:/dataset/1000/5\717.bin
# 正在处理第717个文件
# K:/dataset/1000/5\718.bin
# 正在处理第718个文件
# K:/dataset/1000/5\719.bin
# 正在处理第719个文件
# K:/dataset/1000/5\720.bin
# 正在处理第720个文件
# K:/dataset/1000/5\721.bin
# 正在处理第721个文件
# K:/dataset/1000/5\722.bin
# 正在处理第722个文件
# K:/dataset/1000/5\723.bin
# 正在处理第723个文件
# K:/dataset/1000/5\724.bin
# 正在处理第724个文件
# K:/dataset/1000/5\725.bin
# 正在处理第725个文件
# K:/dataset/1000/5\726.bin
# 正在处理第726个文件
# K:/dataset/1000/5\727.bin
# 正在处理第727个文件
# K:/dataset/1000/5\728.bin
# 正在处理第728个文件
# K:/dataset/1000/5\729.bin
# 正在处理第729个文件
# K:/dataset/1000/5\730.bin
# 正在处理第730个文件
# K:/dataset/1000/5\731.bin
# 正在处理第731个文件
# K:/dataset/1000/5\732.bin
# 正在处理第732个文件
# K:/dataset/1000/5\733.bin
# 正在处理第733个文件
# K:/dataset/1000/5\734.bin
# 正在处理第734个文件
# K:/dataset/1000/5\735.bin
# 正在处理第735个文件
# K:/dataset/1000/5\736.bin
# 正在处理第736个文件
# K:/dataset/1000/5\737.bin
# 正在处理第737个文件
# K:/dataset/1000/5\738.bin
# 正在处理第738个文件
# K:/dataset/1000/5\739.bin
# 正在处理第739个文件
# K:/dataset/1000/5\740.bin
# 正在处理第740个文件
# K:/dataset/1000/5\741.bin
# 正在处理第741个文件
# K:/dataset/1000/5\742.bin
# 正在处理第742个文件
# K:/dataset/1000/5\743.bin
# 正在处理第743个文件
# K:/dataset/1000/5\744.bin
# 正在处理第744个文件
# K:/dataset/1000/5\745.bin
# 正在处理第745个文件
# K:/dataset/1000/5\746.bin
# 正在处理第746个文件
# K:/dataset/1000/5\747.bin
# 正在处理第747个文件
# K:/dataset/1000/5\748.bin
# 正在处理第748个文件
# K:/dataset/1000/5\749.bin
# 正在处理第749个文件
# K:/dataset/1000/5\750.bin
# 正在处理第750个文件
# K:/dataset/1000/5\751.bin
# 正在处理第751个文件
# K:/dataset/1000/5\752.bin
# 正在处理第752个文件
# K:/dataset/1000/5\753.bin
# 正在处理第753个文件
# K:/dataset/1000/5\754.bin
# 正在处理第754个文件
# K:/dataset/1000/5\755.bin
# 正在处理第755个文件
# K:/dataset/1000/5\756.bin
# 正在处理第756个文件
# K:/dataset/1000/5\757.bin
# 正在处理第757个文件
# K:/dataset/1000/5\758.bin
# 正在处理第758个文件
# K:/dataset/1000/5\759.bin
# 正在处理第759个文件
# K:/dataset/1000/5\760.bin
# 正在处理第760个文件
# K:/dataset/1000/5\761.bin
# 正在处理第761个文件
# K:/dataset/1000/5\762.bin
# 正在处理第762个文件
# K:/dataset/1000/5\763.bin
# 正在处理第763个文件
# K:/dataset/1000/5\764.bin
# 正在处理第764个文件
# K:/dataset/1000/5\765.bin
# 正在处理第765个文件
# K:/dataset/1000/5\766.bin
# 正在处理第766个文件
# K:/dataset/1000/5\767.bin
# 正在处理第767个文件
# K:/dataset/1000/5\768.bin
# 正在处理第768个文件
# K:/dataset/1000/5\769.bin
# 正在处理第769个文件
# K:/dataset/1000/5\770.bin
# 正在处理第770个文件
# K:/dataset/1000/5\771.bin
# 正在处理第771个文件
# K:/dataset/1000/5\772.bin
# 正在处理第772个文件
# K:/dataset/1000/5\773.bin
# 正在处理第773个文件
# K:/dataset/1000/5\774.bin
# 正在处理第774个文件
# K:/dataset/1000/5\775.bin
# 正在处理第775个文件
# K:/dataset/1000/5\776.bin
# 正在处理第776个文件
# K:/dataset/1000/5\777.bin
# 正在处理第777个文件
# K:/dataset/1000/5\778.bin
# 正在处理第778个文件
# K:/dataset/1000/5\779.bin
# 正在处理第779个文件
# K:/dataset/1000/5\780.bin
# 正在处理第780个文件
# K:/dataset/1000/5\781.bin
# 正在处理第781个文件
# K:/dataset/1000/5\782.bin
# 正在处理第782个文件
# K:/dataset/1000/5\783.bin
# 正在处理第783个文件
# K:/dataset/1000/5\784.bin
# 正在处理第784个文件
# K:/dataset/1000/5\785.bin
# 正在处理第785个文件
# K:/dataset/1000/5\786.bin
# 正在处理第786个文件
# K:/dataset/1000/5\787.bin
# 正在处理第787个文件
# K:/dataset/1000/5\788.bin
# 正在处理第788个文件
# K:/dataset/1000/5\789.bin
# 正在处理第789个文件
# K:/dataset/1000/5\790.bin
# 正在处理第790个文件
# K:/dataset/1000/5\791.bin
# 正在处理第791个文件
# K:/dataset/1000/5\792.bin
# 正在处理第792个文件
# K:/dataset/1000/5\793.bin
# 正在处理第793个文件
# K:/dataset/1000/5\794.bin
# 正在处理第794个文件
# K:/dataset/1000/5\795.bin
# 正在处理第795个文件
# K:/dataset/1000/5\796.bin
# 正在处理第796个文件
# K:/dataset/1000/5\797.bin
# 正在处理第797个文件
# K:/dataset/1000/5\798.bin
# 正在处理第798个文件
# K:/dataset/1000/5\799.bin
# 正在处理第799个文件
# K:/dataset/1000/5\800.bin
# 正在处理第800个文件
# K:/dataset/1000/5\801.bin
# 正在处理第801个文件
# K:/dataset/1000/5\802.bin
# 正在处理第802个文件
# K:/dataset/1000/5\803.bin
# 正在处理第803个文件
# K:/dataset/1000/5\804.bin
# 正在处理第804个文件
# K:/dataset/1000/5\805.bin
# 正在处理第805个文件
# K:/dataset/1000/5\806.bin
# 正在处理第806个文件
# K:/dataset/1000/5\807.bin
# 正在处理第807个文件
# K:/dataset/1000/5\808.bin
# 正在处理第808个文件
# K:/dataset/1000/5\809.bin
# 正在处理第809个文件
# K:/dataset/1000/5\810.bin
# 正在处理第810个文件
# K:/dataset/1000/5\811.bin
# 正在处理第811个文件
# K:/dataset/1000/5\812.bin
# 正在处理第812个文件
# K:/dataset/1000/5\813.bin
# 正在处理第813个文件
# K:/dataset/1000/5\814.bin
# 正在处理第814个文件
# K:/dataset/1000/5\815.bin
# 正在处理第815个文件
# K:/dataset/1000/5\816.bin
# 正在处理第816个文件
# K:/dataset/1000/5\817.bin
# 正在处理第817个文件
# K:/dataset/1000/5\818.bin
# 正在处理第818个文件
# K:/dataset/1000/5\819.bin
# 正在处理第819个文件
# K:/dataset/1000/5\820.bin
# 正在处理第820个文件
# K:/dataset/1000/5\821.bin
# 正在处理第821个文件
# K:/dataset/1000/5\822.bin
# 正在处理第822个文件
# K:/dataset/1000/5\823.bin
# 正在处理第823个文件
# K:/dataset/1000/5\824.bin
# 正在处理第824个文件
# K:/dataset/1000/5\825.bin
# 正在处理第825个文件
# K:/dataset/1000/5\826.bin
# 正在处理第826个文件
# K:/dataset/1000/5\827.bin
# 正在处理第827个文件
# K:/dataset/1000/5\828.bin
# 正在处理第828个文件
# K:/dataset/1000/5\829.bin
# 正在处理第829个文件
# K:/dataset/1000/5\830.bin
# 正在处理第830个文件
# K:/dataset/1000/5\831.bin
# 正在处理第831个文件
# K:/dataset/1000/5\832.bin
# 正在处理第832个文件
# K:/dataset/1000/5\833.bin
# 正在处理第833个文件
# K:/dataset/1000/5\834.bin
# 正在处理第834个文件
# K:/dataset/1000/5\835.bin
# 正在处理第835个文件
# K:/dataset/1000/5\836.bin
# 正在处理第836个文件
# K:/dataset/1000/5\837.bin
# 正在处理第837个文件
# K:/dataset/1000/5\838.bin
# 正在处理第838个文件
# K:/dataset/1000/5\839.bin
# 正在处理第839个文件
# K:/dataset/1000/5\840.bin
# 正在处理第840个文件
# K:/dataset/1000/5\841.bin
# 正在处理第841个文件
# K:/dataset/1000/5\842.bin
# 正在处理第842个文件
# K:/dataset/1000/5\843.bin
# 正在处理第843个文件
# K:/dataset/1000/5\844.bin
# 正在处理第844个文件
# K:/dataset/1000/5\845.bin
# 正在处理第845个文件
# K:/dataset/1000/5\846.bin
# 正在处理第846个文件
# K:/dataset/1000/5\847.bin
# 正在处理第847个文件
# K:/dataset/1000/5\848.bin
# 正在处理第848个文件
# K:/dataset/1000/5\849.bin
# 正在处理第849个文件
# K:/dataset/1000/5\850.bin
# 正在处理第850个文件
# K:/dataset/1000/5\851.bin
# 正在处理第851个文件
# K:/dataset/1000/5\852.bin
# 正在处理第852个文件
# K:/dataset/1000/5\853.bin
# 正在处理第853个文件
# K:/dataset/1000/5\854.bin
# 正在处理第854个文件
# K:/dataset/1000/5\855.bin
# 正在处理第855个文件
# K:/dataset/1000/5\856.bin
# 正在处理第856个文件
# K:/dataset/1000/5\857.bin
# 正在处理第857个文件
# K:/dataset/1000/5\858.bin
# 正在处理第858个文件
# K:/dataset/1000/5\859.bin
# 正在处理第859个文件
# K:/dataset/1000/5\860.bin
# 正在处理第860个文件
# K:/dataset/1000/5\861.bin
# 正在处理第861个文件
# K:/dataset/1000/5\862.bin
# 正在处理第862个文件
# K:/dataset/1000/5\863.bin
# 正在处理第863个文件
# K:/dataset/1000/5\864.bin
# 正在处理第864个文件
# K:/dataset/1000/5\865.bin
# 正在处理第865个文件
# K:/dataset/1000/5\866.bin
# 正在处理第866个文件
# K:/dataset/1000/5\867.bin
# 正在处理第867个文件
# K:/dataset/1000/5\868.bin
# 正在处理第868个文件
# K:/dataset/1000/5\869.bin
# 正在处理第869个文件
# K:/dataset/1000/5\870.bin
# 正在处理第870个文件
# K:/dataset/1000/5\871.bin
# 正在处理第871个文件
# K:/dataset/1000/5\872.bin
# 正在处理第872个文件
# K:/dataset/1000/5\873.bin
# 正在处理第873个文件
# K:/dataset/1000/5\874.bin
# 正在处理第874个文件
# K:/dataset/1000/5\875.bin
# 正在处理第875个文件
# K:/dataset/1000/5\876.bin
# 正在处理第876个文件
# K:/dataset/1000/5\877.bin
# 正在处理第877个文件
# K:/dataset/1000/5\878.bin
# 正在处理第878个文件
# K:/dataset/1000/5\879.bin
# 正在处理第879个文件
# K:/dataset/1000/5\880.bin
# 正在处理第880个文件
# K:/dataset/1000/5\881.bin
# 正在处理第881个文件
# K:/dataset/1000/5\882.bin
# 正在处理第882个文件
# K:/dataset/1000/5\883.bin
# 正在处理第883个文件
# K:/dataset/1000/5\884.bin
# 正在处理第884个文件
# K:/dataset/1000/5\885.bin
# 正在处理第885个文件
# K:/dataset/1000/5\886.bin
# 正在处理第886个文件
# K:/dataset/1000/5\887.bin
# 正在处理第887个文件
# K:/dataset/1000/5\888.bin
# 正在处理第888个文件
# K:/dataset/1000/5\889.bin
# 正在处理第889个文件
# K:/dataset/1000/5\890.bin
# 正在处理第890个文件
# K:/dataset/1000/5\891.bin
# 正在处理第891个文件
# K:/dataset/1000/5\892.bin
# 正在处理第892个文件
# K:/dataset/1000/5\893.bin
# 正在处理第893个文件
# K:/dataset/1000/5\894.bin
# 正在处理第894个文件
# K:/dataset/1000/5\895.bin
# 正在处理第895个文件
# K:/dataset/1000/5\896.bin
# 正在处理第896个文件
# K:/dataset/1000/5\897.bin
# 正在处理第897个文件
# K:/dataset/1000/5\898.bin
# 正在处理第898个文件
# K:/dataset/1000/5\899.bin
# 正在处理第899个文件
# K:/dataset/1000/5\900.bin
# 正在处理第900个文件
# K:/dataset/1000/5\901.bin
# 正在处理第901个文件
# K:/dataset/1000/5\902.bin
# 正在处理第902个文件
# K:/dataset/1000/5\903.bin
# 正在处理第903个文件
# K:/dataset/1000/5\904.bin
# 正在处理第904个文件
# K:/dataset/1000/5\905.bin
# 正在处理第905个文件
# K:/dataset/1000/5\906.bin
# 正在处理第906个文件
# K:/dataset/1000/5\907.bin
# 正在处理第907个文件
# K:/dataset/1000/5\908.bin
# 正在处理第908个文件
# K:/dataset/1000/5\909.bin
# 正在处理第909个文件
# K:/dataset/1000/5\910.bin
# 正在处理第910个文件
# K:/dataset/1000/5\911.bin
# 正在处理第911个文件
# K:/dataset/1000/5\912.bin
# 正在处理第912个文件
# K:/dataset/1000/5\913.bin
# 正在处理第913个文件
# K:/dataset/1000/5\914.bin
# 正在处理第914个文件
# K:/dataset/1000/5\915.bin
# 正在处理第915个文件
# K:/dataset/1000/5\916.bin
# 正在处理第916个文件
# K:/dataset/1000/5\917.bin
# 正在处理第917个文件
# K:/dataset/1000/5\918.bin
# 正在处理第918个文件
# K:/dataset/1000/5\919.bin
# 正在处理第919个文件
# K:/dataset/1000/5\920.bin
# 正在处理第920个文件
# K:/dataset/1000/5\921.bin
# 正在处理第921个文件
# K:/dataset/1000/5\922.bin
# 正在处理第922个文件
# K:/dataset/1000/5\923.bin
# 正在处理第923个文件
# K:/dataset/1000/5\924.bin
# 正在处理第924个文件
# K:/dataset/1000/5\925.bin
# 正在处理第925个文件
# K:/dataset/1000/5\926.bin
# 正在处理第926个文件
# K:/dataset/1000/5\927.bin
# 正在处理第927个文件
# K:/dataset/1000/5\928.bin
# 正在处理第928个文件
# K:/dataset/1000/5\929.bin
# 正在处理第929个文件
# K:/dataset/1000/5\930.bin
# 正在处理第930个文件
# K:/dataset/1000/5\931.bin
# 正在处理第931个文件
# K:/dataset/1000/5\932.bin
# 正在处理第932个文件
# K:/dataset/1000/5\933.bin
# 正在处理第933个文件
# K:/dataset/1000/5\934.bin
# 正在处理第934个文件
# K:/dataset/1000/5\935.bin
# 正在处理第935个文件
# K:/dataset/1000/5\936.bin
# 正在处理第936个文件
# K:/dataset/1000/5\937.bin
# 正在处理第937个文件
# K:/dataset/1000/5\938.bin
# 正在处理第938个文件
# K:/dataset/1000/5\939.bin
# 正在处理第939个文件
# K:/dataset/1000/5\940.bin
# 正在处理第940个文件
# K:/dataset/1000/5\941.bin
# 正在处理第941个文件
# K:/dataset/1000/5\942.bin
# 正在处理第942个文件
# K:/dataset/1000/5\943.bin
# 正在处理第943个文件
# K:/dataset/1000/5\944.bin
# 正在处理第944个文件
# K:/dataset/1000/5\945.bin
# 正在处理第945个文件
# K:/dataset/1000/5\946.bin
# 正在处理第946个文件
# K:/dataset/1000/5\947.bin
# 正在处理第947个文件
# K:/dataset/1000/5\948.bin
# 正在处理第948个文件
# K:/dataset/1000/5\949.bin
# 正在处理第949个文件
# K:/dataset/1000/5\950.bin
# 正在处理第950个文件
# K:/dataset/1000/5\951.bin
# 正在处理第951个文件
# K:/dataset/1000/5\952.bin
# 正在处理第952个文件
# K:/dataset/1000/5\953.bin
# 正在处理第953个文件
# K:/dataset/1000/5\954.bin
# 正在处理第954个文件
# K:/dataset/1000/5\955.bin
# 正在处理第955个文件
# K:/dataset/1000/5\956.bin
# 正在处理第956个文件
# K:/dataset/1000/5\957.bin
# 正在处理第957个文件
# K:/dataset/1000/5\958.bin
# 正在处理第958个文件
# K:/dataset/1000/5\959.bin
# 正在处理第959个文件
# K:/dataset/1000/5\960.bin
# 正在处理第960个文件
# K:/dataset/1000/5\961.bin
# 正在处理第961个文件
# K:/dataset/1000/5\962.bin
# 正在处理第962个文件
# K:/dataset/1000/5\963.bin
# 正在处理第963个文件
# K:/dataset/1000/5\964.bin
# 正在处理第964个文件
# K:/dataset/1000/5\965.bin
# 正在处理第965个文件
# K:/dataset/1000/5\966.bin
# 正在处理第966个文件
# K:/dataset/1000/5\967.bin
# 正在处理第967个文件
# K:/dataset/1000/5\968.bin
# 正在处理第968个文件
# K:/dataset/1000/5\969.bin
# 正在处理第969个文件
# K:/dataset/1000/5\970.bin
# 正在处理第970个文件
# K:/dataset/1000/5\971.bin
# 正在处理第971个文件
# K:/dataset/1000/5\972.bin
# 正在处理第972个文件
# K:/dataset/1000/5\973.bin
# 正在处理第973个文件
# K:/dataset/1000/5\974.bin
# 正在处理第974个文件
# K:/dataset/1000/5\975.bin
# 正在处理第975个文件
# K:/dataset/1000/5\976.bin
# 正在处理第976个文件
# K:/dataset/1000/5\977.bin
# 正在处理第977个文件
# K:/dataset/1000/5\978.bin
# 正在处理第978个文件
# K:/dataset/1000/5\979.bin
# 正在处理第979个文件
# K:/dataset/1000/5\980.bin
# 正在处理第980个文件
# K:/dataset/1000/5\981.bin
# 正在处理第981个文件
# K:/dataset/1000/5\982.bin
# 正在处理第982个文件
# K:/dataset/1000/5\983.bin
# 正在处理第983个文件
# K:/dataset/1000/5\984.bin
# 正在处理第984个文件
# K:/dataset/1000/5\985.bin
# 正在处理第985个文件
# K:/dataset/1000/5\986.bin
# 正在处理第986个文件
# K:/dataset/1000/5\987.bin
# 正在处理第987个文件
# K:/dataset/1000/5\988.bin
# 正在处理第988个文件
# K:/dataset/1000/5\989.bin
# 正在处理第989个文件
# K:/dataset/1000/5\990.bin
# 正在处理第990个文件
# K:/dataset/1000/5\991.bin
# 正在处理第991个文件
# K:/dataset/1000/5\992.bin
# 正在处理第992个文件
# K:/dataset/1000/5\993.bin
# 正在处理第993个文件
# K:/dataset/1000/5\994.bin
# 正在处理第994个文件
# K:/dataset/1000/5\995.bin
# 正在处理第995个文件
# K:/dataset/1000/5\996.bin
# 正在处理第996个文件
# K:/dataset/1000/5\997.bin
# 正在处理第997个文件
# K:/dataset/1000/5\998.bin
# 正在处理第998个文件
# K:/dataset/1000/5\999.bin
# 正在处理第999个文件
# K:/dataset/1000/5\1000.bin
# 正在处理第1000个文件
# [5]
# 当前类别为：5
# K:/dataset/1000/5
# ['K:/dataset/1000/5\\1.bin', 'K:/dataset/1000/5\\10.bin', 'K:/dataset/1000/5\\100.bin', 'K:/dataset/1000/5\\1000.bin', 'K:/dataset/1000/5\\101.bin', 'K:/dataset/1000/5\\102.bin', 'K:/dataset/1000/5\\103.bin', 'K:/dataset/1000/5\\104.bin', 'K:/dataset/1000/5\\105.bin', 'K:/dataset/1000/5\\106.bin', 'K:/dataset/1000/5\\107.bin', 'K:/dataset/1000/5\\108.bin', 'K:/dataset/1000/5\\109.bin', 'K:/dataset/1000/5\\11.bin', 'K:/dataset/1000/5\\110.bin', 'K:/dataset/1000/5\\111.bin', 'K:/dataset/1000/5\\112.bin', 'K:/dataset/1000/5\\113.bin', 'K:/dataset/1000/5\\114.bin', 'K:/dataset/1000/5\\115.bin', 'K:/dataset/1000/5\\116.bin', 'K:/dataset/1000/5\\117.bin', 'K:/dataset/1000/5\\118.bin', 'K:/dataset/1000/5\\119.bin', 'K:/dataset/1000/5\\12.bin', 'K:/dataset/1000/5\\120.bin', 'K:/dataset/1000/5\\121.bin', 'K:/dataset/1000/5\\122.bin', 'K:/dataset/1000/5\\123.bin', 'K:/dataset/1000/5\\124.bin', 'K:/dataset/1000/5\\125.bin', 'K:/dataset/1000/5\\126.bin', 'K:/dataset/1000/5\\127.bin', 'K:/dataset/1000/5\\128.bin', 'K:/dataset/1000/5\\129.bin', 'K:/dataset/1000/5\\13.bin', 'K:/dataset/1000/5\\130.bin', 'K:/dataset/1000/5\\131.bin', 'K:/dataset/1000/5\\132.bin', 'K:/dataset/1000/5\\133.bin', 'K:/dataset/1000/5\\134.bin', 'K:/dataset/1000/5\\135.bin', 'K:/dataset/1000/5\\136.bin', 'K:/dataset/1000/5\\137.bin', 'K:/dataset/1000/5\\138.bin', 'K:/dataset/1000/5\\139.bin', 'K:/dataset/1000/5\\14.bin', 'K:/dataset/1000/5\\140.bin', 'K:/dataset/1000/5\\141.bin', 'K:/dataset/1000/5\\142.bin', 'K:/dataset/1000/5\\143.bin', 'K:/dataset/1000/5\\144.bin', 'K:/dataset/1000/5\\145.bin', 'K:/dataset/1000/5\\146.bin', 'K:/dataset/1000/5\\147.bin', 'K:/dataset/1000/5\\148.bin', 'K:/dataset/1000/5\\149.bin', 'K:/dataset/1000/5\\15.bin', 'K:/dataset/1000/5\\150.bin', 'K:/dataset/1000/5\\151.bin', 'K:/dataset/1000/5\\152.bin', 'K:/dataset/1000/5\\153.bin', 'K:/dataset/1000/5\\154.bin', 'K:/dataset/1000/5\\155.bin', 'K:/dataset/1000/5\\156.bin', 'K:/dataset/1000/5\\157.bin', 'K:/dataset/1000/5\\158.bin', 'K:/dataset/1000/5\\159.bin', 'K:/dataset/1000/5\\16.bin', 'K:/dataset/1000/5\\160.bin', 'K:/dataset/1000/5\\161.bin', 'K:/dataset/1000/5\\162.bin', 'K:/dataset/1000/5\\163.bin', 'K:/dataset/1000/5\\164.bin', 'K:/dataset/1000/5\\165.bin', 'K:/dataset/1000/5\\166.bin', 'K:/dataset/1000/5\\167.bin', 'K:/dataset/1000/5\\168.bin', 'K:/dataset/1000/5\\169.bin', 'K:/dataset/1000/5\\17.bin', 'K:/dataset/1000/5\\170.bin', 'K:/dataset/1000/5\\171.bin', 'K:/dataset/1000/5\\172.bin', 'K:/dataset/1000/5\\173.bin', 'K:/dataset/1000/5\\174.bin', 'K:/dataset/1000/5\\175.bin', 'K:/dataset/1000/5\\176.bin', 'K:/dataset/1000/5\\177.bin', 'K:/dataset/1000/5\\178.bin', 'K:/dataset/1000/5\\179.bin', 'K:/dataset/1000/5\\18.bin', 'K:/dataset/1000/5\\180.bin', 'K:/dataset/1000/5\\181.bin', 'K:/dataset/1000/5\\182.bin', 'K:/dataset/1000/5\\183.bin', 'K:/dataset/1000/5\\184.bin', 'K:/dataset/1000/5\\185.bin', 'K:/dataset/1000/5\\186.bin', 'K:/dataset/1000/5\\187.bin', 'K:/dataset/1000/5\\188.bin', 'K:/dataset/1000/5\\189.bin', 'K:/dataset/1000/5\\19.bin', 'K:/dataset/1000/5\\190.bin', 'K:/dataset/1000/5\\191.bin', 'K:/dataset/1000/5\\192.bin', 'K:/dataset/1000/5\\193.bin', 'K:/dataset/1000/5\\194.bin', 'K:/dataset/1000/5\\195.bin', 'K:/dataset/1000/5\\196.bin', 'K:/dataset/1000/5\\197.bin', 'K:/dataset/1000/5\\198.bin', 'K:/dataset/1000/5\\199.bin', 'K:/dataset/1000/5\\2.bin', 'K:/dataset/1000/5\\20.bin', 'K:/dataset/1000/5\\200.bin', 'K:/dataset/1000/5\\201.bin', 'K:/dataset/1000/5\\202.bin', 'K:/dataset/1000/5\\203.bin', 'K:/dataset/1000/5\\204.bin', 'K:/dataset/1000/5\\205.bin', 'K:/dataset/1000/5\\206.bin', 'K:/dataset/1000/5\\207.bin', 'K:/dataset/1000/5\\208.bin', 'K:/dataset/1000/5\\209.bin', 'K:/dataset/1000/5\\21.bin', 'K:/dataset/1000/5\\210.bin', 'K:/dataset/1000/5\\211.bin', 'K:/dataset/1000/5\\212.bin', 'K:/dataset/1000/5\\213.bin', 'K:/dataset/1000/5\\214.bin', 'K:/dataset/1000/5\\215.bin', 'K:/dataset/1000/5\\216.bin', 'K:/dataset/1000/5\\217.bin', 'K:/dataset/1000/5\\218. ...
# K:/dataset/1000/5\1.bin
# 正在处理第1个文件
# K:/dataset/1000/5\2.bin
# 正在处理第2个文件
# K:/dataset/1000/5\3.bin
# 正在处理第3个文件
# K:/dataset/1000/5\4.bin
# 正在处理第4个文件
# K:/dataset/1000/5\5.bin
# 正在处理第5个文件
# K:/dataset/1000/5\6.bin
# 正在处理第6个文件
# K:/dataset/1000/5\7.bin
# 正在处理第7个文件
# K:/dataset/1000/5\8.bin
# 正在处理第8个文件
# K:/dataset/1000/5\9.bin
# 正在处理第9个文件
# K:/dataset/1000/5\10.bin
# 正在处理第10个文件
# K:/dataset/1000/5\11.bin
# 正在处理第11个文件
# K:/dataset/1000/5\12.bin
# 正在处理第12个文件
# K:/dataset/1000/5\13.bin
# 正在处理第13个文件
# K:/dataset/1000/5\14.bin
# 正在处理第14个文件
# K:/dataset/1000/5\15.bin
# 正在处理第15个文件
# K:/dataset/1000/5\16.bin
# 正在处理第16个文件
# K:/dataset/1000/5\17.bin
# 正在处理第17个文件
# K:/dataset/1000/5\18.bin
# 正在处理第18个文件
# K:/dataset/1000/5\19.bin
# 正在处理第19个文件
# K:/dataset/1000/5\20.bin
# 正在处理第20个文件
# K:/dataset/1000/5\21.bin
# 正在处理第21个文件
# K:/dataset/1000/5\22.bin
# 正在处理第22个文件
# K:/dataset/1000/5\23.bin
# 正在处理第23个文件
# K:/dataset/1000/5\24.bin
# 正在处理第24个文件
# K:/dataset/1000/5\25.bin
# 正在处理第25个文件
# K:/dataset/1000/5\26.bin
# 正在处理第26个文件
# K:/dataset/1000/5\27.bin
# 正在处理第27个文件
# K:/dataset/1000/5\28.bin
# 正在处理第28个文件
# K:/dataset/1000/5\29.bin
# 正在处理第29个文件
# K:/dataset/1000/5\30.bin
# 正在处理第30个文件
# K:/dataset/1000/5\31.bin
# 正在处理第31个文件
# K:/dataset/1000/5\32.bin
# 正在处理第32个文件
# K:/dataset/1000/5\33.bin
# 正在处理第33个文件
# K:/dataset/1000/5\34.bin
# 正在处理第34个文件
# K:/dataset/1000/5\35.bin
# 正在处理第35个文件
# K:/dataset/1000/5\36.bin
# 正在处理第36个文件
# K:/dataset/1000/5\37.bin
# 正在处理第37个文件
# K:/dataset/1000/5\38.bin
# 正在处理第38个文件
# K:/dataset/1000/5\39.bin
# 正在处理第39个文件
# K:/dataset/1000/5\40.bin
# 正在处理第40个文件
# K:/dataset/1000/5\41.bin
# 正在处理第41个文件
# K:/dataset/1000/5\42.bin
# 正在处理第42个文件
# K:/dataset/1000/5\43.bin
# 正在处理第43个文件
# K:/dataset/1000/5\44.bin
# 正在处理第44个文件
# K:/dataset/1000/5\45.bin
# 正在处理第45个文件
# K:/dataset/1000/5\46.bin
# 正在处理第46个文件
# K:/dataset/1000/5\47.bin
# 正在处理第47个文件
# K:/dataset/1000/5\48.bin
# 正在处理第48个文件
# K:/dataset/1000/5\49.bin
# 正在处理第49个文件
# K:/dataset/1000/5\50.bin
# 正在处理第50个文件
# K:/dataset/1000/5\51.bin
# 正在处理第51个文件
# K:/dataset/1000/5\52.bin
# 正在处理第52个文件
# K:/dataset/1000/5\53.bin
# 正在处理第53个文件
# K:/dataset/1000/5\54.bin
# 正在处理第54个文件
# K:/dataset/1000/5\55.bin
# 正在处理第55个文件
# K:/dataset/1000/5\56.bin
# 正在处理第56个文件
# K:/dataset/1000/5\57.bin
# 正在处理第57个文件
# K:/dataset/1000/5\58.bin
# 正在处理第58个文件
# K:/dataset/1000/5\59.bin
# 正在处理第59个文件
# K:/dataset/1000/5\60.bin
# 正在处理第60个文件
# ...
# K:/dataset/1000/5\585.bin
# 正在处理第585个文件
# K:/dataset/1000/5\586.bin
# 正在处理第586个文件
# K:/dataset/1000/5\587.bin
# 正在处理第587个文件
# K:/dataset/1000/5\588.bin
# 正在处理第588个文件
# K:/dataset/1000/5\589.bin
# 正在处理第589个文件
# K:/dataset/1000/5\590.bin
# 正在处理第590个文件
# K:/dataset/1000/5\591.bin
# 正在处理第591个文件
# K:/dataset/1000/5\592.bin
# 正在处理第592个文件
# K:/dataset/1000/5\593.bin
# 正在处理第593个文件
# K:/dataset/1000/5\594.bin
# 正在处理第594个文件
# K:/dataset/1000/5\595.bin
# 正在处理第595个文件
# K:/dataset/1000/5\596.bin
# 正在处理第596个文件
# K:/dataset/1000/5\597.bin
# 正在处理第597个文件
# K:/dataset/1000/5\598.bin
# 正在处理第598个文件
# K:/dataset/1000/5\599.bin
# 正在处理第599个文件
# K:/dataset/1000/5\600.bin
# 正在处理第600个文件
# K:/dataset/1000/5\601.bin
# 正在处理第601个文件
# K:/dataset/1000/5\602.bin
# 正在处理第602个文件
# K:/dataset/1000/5\603.bin
# 正在处理第603个文件
# K:/dataset/1000/5\604.bin
# 正在处理第604个文件
# K:/dataset/1000/5\605.bin
# 正在处理第605个文件
# K:/dataset/1000/5\606.bin
# 正在处理第606个文件
# K:/dataset/1000/5\607.bin
# 正在处理第607个文件
# K:/dataset/1000/5\608.bin
# 正在处理第608个文件
# K:/dataset/1000/5\609.bin
# 正在处理第609个文件
# K:/dataset/1000/5\610.bin
# 正在处理第610个文件
# K:/dataset/1000/5\611.bin
# 正在处理第611个文件
# K:/dataset/1000/5\612.bin
# 正在处理第612个文件
# K:/dataset/1000/5\613.bin
# 正在处理第613个文件
# K:/dataset/1000/5\614.bin
# 正在处理第614个文件
# K:/dataset/1000/5\615.bin
# 正在处理第615个文件
# K:/dataset/1000/5\616.bin
# 正在处理第616个文件
# K:/dataset/1000/5\617.bin
# 正在处理第617个文件
# K:/dataset/1000/5\618.bin
# 正在处理第618个文件
# K:/dataset/1000/5\619.bin
# 正在处理第619个文件
# K:/dataset/1000/5\620.bin
# 正在处理第620个文件
# K:/dataset/1000/5\621.bin
# 正在处理第621个文件
# K:/dataset/1000/5\622.bin
# 正在处理第622个文件
# K:/dataset/1000/5\623.bin
# 正在处理第623个文件
# K:/dataset/1000/5\624.bin
# 正在处理第624个文件
# K:/dataset/1000/5\625.bin
# 正在处理第625个文件
# K:/dataset/1000/5\626.bin
# 正在处理第626个文件
# K:/dataset/1000/5\627.bin
# 正在处理第627个文件
# K:/dataset/1000/5\628.bin
# 正在处理第628个文件
# K:/dataset/1000/5\629.bin
# 正在处理第629个文件
# K:/dataset/1000/5\630.bin
# 正在处理第630个文件
# K:/dataset/1000/5\631.bin
# 正在处理第631个文件
# K:/dataset/1000/5\632.bin
# 正在处理第632个文件
# K:/dataset/1000/5\633.bin
# 正在处理第633个文件
# K:/dataset/1000/5\634.bin
# 正在处理第634个文件
# K:/dataset/1000/5\635.bin
# 正在处理第635个文件
# K:/dataset/1000/5\636.bin
# 正在处理第636个文件
# K:/dataset/1000/5\637.bin
# 正在处理第637个文件
# K:/dataset/1000/5\638.bin
# 正在处理第638个文件
# K:/dataset/1000/5\639.bin
# 正在处理第639个文件
# K:/dataset/1000/5\640.bin
# 正在处理第640个文件
# K:/dataset/1000/5\641.bin
# 正在处理第641个文件
# K:/dataset/1000/5\642.bin
# 正在处理第642个文件
# K:/dataset/1000/5\643.bin
# 正在处理第643个文件
# K:/dataset/1000/5\644.bin
# 正在处理第644个文件
# K:/dataset/1000/5\645.bin
# 正在处理第645个文件
# K:/dataset/1000/5\646.bin
# 正在处理第646个文件
# K:/dataset/1000/5\647.bin
# 正在处理第647个文件
# K:/dataset/1000/5\648.bin
# 正在处理第648个文件
# K:/dataset/1000/5\649.bin
# 正在处理第649个文件
# K:/dataset/1000/5\650.bin
# 正在处理第650个文件
# K:/dataset/1000/5\651.bin
# 正在处理第651个文件
# K:/dataset/1000/5\652.bin
# 正在处理第652个文件
# K:/dataset/1000/5\653.bin
# 正在处理第653个文件
# K:/dataset/1000/5\654.bin
# 正在处理第654个文件
# K:/dataset/1000/5\655.bin
# 正在处理第655个文件
# K:/dataset/1000/5\656.bin
# 正在处理第656个文件
# K:/dataset/1000/5\657.bin
# 正在处理第657个文件
# K:/dataset/1000/5\658.bin
# 正在处理第658个文件
# K:/dataset/1000/5\659.bin
# 正在处理第659个文件
# K:/dataset/1000/5\660.bin
# 正在处理第660个文件
# K:/dataset/1000/5\661.bin
# 正在处理第661个文件
# K:/dataset/1000/5\662.bin
# 正在处理第662个文件
# K:/dataset/1000/5\663.bin
# 正在处理第663个文件
# K:/dataset/1000/5\664.bin
# 正在处理第664个文件
# K:/dataset/1000/5\665.bin
# 正在处理第665个文件
# K:/dataset/1000/5\666.bin
# 正在处理第666个文件
# K:/dataset/1000/5\667.bin
# 正在处理第667个文件
# K:/dataset/1000/5\668.bin
# 正在处理第668个文件
# K:/dataset/1000/5\669.bin
# 正在处理第669个文件
# K:/dataset/1000/5\670.bin
# 正在处理第670个文件
# K:/dataset/1000/5\671.bin
# 正在处理第671个文件
# K:/dataset/1000/5\672.bin
# 正在处理第672个文件
# K:/dataset/1000/5\673.bin
# 正在处理第673个文件
# K:/dataset/1000/5\674.bin
# 正在处理第674个文件
# K:/dataset/1000/5\675.bin
# 正在处理第675个文件
# K:/dataset/1000/5\676.bin
# 正在处理第676个文件
# K:/dataset/1000/5\677.bin
# 正在处理第677个文件
# K:/dataset/1000/5\678.bin
# 正在处理第678个文件
# K:/dataset/1000/5\679.bin
# 正在处理第679个文件
# K:/dataset/1000/5\680.bin
# 正在处理第680个文件
# K:/dataset/1000/5\681.bin
# 正在处理第681个文件
# K:/dataset/1000/5\682.bin
# 正在处理第682个文件
# K:/dataset/1000/5\683.bin
# 正在处理第683个文件
# K:/dataset/1000/5\684.bin
# 正在处理第684个文件
# K:/dataset/1000/5\685.bin
# 正在处理第685个文件
# K:/dataset/1000/5\686.bin
# 正在处理第686个文件
# K:/dataset/1000/5\687.bin
# 正在处理第687个文件
# K:/dataset/1000/5\688.bin
# 正在处理第688个文件
# K:/dataset/1000/5\689.bin
# 正在处理第689个文件
# K:/dataset/1000/5\690.bin
# 正在处理第690个文件
# K:/dataset/1000/5\691.bin
# 正在处理第691个文件
# K:/dataset/1000/5\692.bin
# 正在处理第692个文件
# K:/dataset/1000/5\693.bin
# 正在处理第693个文件
# K:/dataset/1000/5\694.bin
# 正在处理第694个文件
# K:/dataset/1000/5\695.bin
# 正在处理第695个文件
# K:/dataset/1000/5\696.bin
# 正在处理第696个文件
# K:/dataset/1000/5\697.bin
# 正在处理第697个文件
# K:/dataset/1000/5\698.bin
# 正在处理第698个文件
# K:/dataset/1000/5\699.bin
# 正在处理第699个文件
# K:/dataset/1000/5\700.bin
# 正在处理第700个文件
# K:/dataset/1000/5\701.bin
# 正在处理第701个文件
# K:/dataset/1000/5\702.bin
# 正在处理第702个文件
# K:/dataset/1000/5\703.bin
# 正在处理第703个文件
# K:/dataset/1000/5\704.bin
# 正在处理第704个文件
# K:/dataset/1000/5\705.bin
# 正在处理第705个文件
# K:/dataset/1000/5\706.bin
# 正在处理第706个文件
# K:/dataset/1000/5\707.bin
# 正在处理第707个文件
# K:/dataset/1000/5\708.bin
# 正在处理第708个文件
# K:/dataset/1000/5\709.bin
# 正在处理第709个文件
# K:/dataset/1000/5\710.bin
# 正在处理第710个文件
# K:/dataset/1000/5\711.bin
# 正在处理第711个文件
# K:/dataset/1000/5\712.bin
# 正在处理第712个文件
# K:/dataset/1000/5\713.bin
# 正在处理第713个文件
# K:/dataset/1000/5\714.bin
# 正在处理第714个文件
# K:/dataset/1000/5\715.bin
# 正在处理第715个文件
# K:/dataset/1000/5\716.bin
# 正在处理第716个文件
# K:/dataset/1000/5\717.bin
# 正在处理第717个文件
# K:/dataset/1000/5\718.bin
# 正在处理第718个文件
# K:/dataset/1000/5\719.bin
# 正在处理第719个文件
# K:/dataset/1000/5\720.bin
# 正在处理第720个文件
# K:/dataset/1000/5\721.bin
# 正在处理第721个文件
# K:/dataset/1000/5\722.bin
# 正在处理第722个文件
# K:/dataset/1000/5\723.bin
# 正在处理第723个文件
# K:/dataset/1000/5\724.bin
# 正在处理第724个文件
# K:/dataset/1000/5\725.bin
# 正在处理第725个文件
# K:/dataset/1000/5\726.bin
# 正在处理第726个文件
# K:/dataset/1000/5\727.bin
# 正在处理第727个文件
# K:/dataset/1000/5\728.bin
# 正在处理第728个文件
# K:/dataset/1000/5\729.bin
# 正在处理第729个文件
# K:/dataset/1000/5\730.bin
# 正在处理第730个文件
# K:/dataset/1000/5\731.bin
# 正在处理第731个文件
# K:/dataset/1000/5\732.bin
# 正在处理第732个文件
# K:/dataset/1000/5\733.bin
# 正在处理第733个文件
# K:/dataset/1000/5\734.bin
# 正在处理第734个文件
# K:/dataset/1000/5\735.bin
# 正在处理第735个文件
# K:/dataset/1000/5\736.bin
# 正在处理第736个文件
# K:/dataset/1000/5\737.bin
# 正在处理第737个文件
# K:/dataset/1000/5\738.bin
# 正在处理第738个文件
# K:/dataset/1000/5\739.bin
# 正在处理第739个文件
# K:/dataset/1000/5\740.bin
# 正在处理第740个文件
# K:/dataset/1000/5\741.bin
# 正在处理第741个文件
# K:/dataset/1000/5\742.bin
# 正在处理第742个文件
# K:/dataset/1000/5\743.bin
# 正在处理第743个文件
# K:/dataset/1000/5\744.bin
# 正在处理第744个文件
# K:/dataset/1000/5\745.bin
# 正在处理第745个文件
# K:/dataset/1000/5\746.bin
# 正在处理第746个文件
# K:/dataset/1000/5\747.bin
# 正在处理第747个文件
# K:/dataset/1000/5\748.bin
# 正在处理第748个文件
# K:/dataset/1000/5\749.bin
# 正在处理第749个文件
# K:/dataset/1000/5\750.bin
# 正在处理第750个文件
# K:/dataset/1000/5\751.bin
# 正在处理第751个文件
# K:/dataset/1000/5\752.bin
# 正在处理第752个文件
# K:/dataset/1000/5\753.bin
# 正在处理第753个文件
# K:/dataset/1000/5\754.bin
# 正在处理第754个文件
# K:/dataset/1000/5\755.bin
# 正在处理第755个文件
# K:/dataset/1000/5\756.bin
# 正在处理第756个文件
# K:/dataset/1000/5\757.bin
# 正在处理第757个文件
# K:/dataset/1000/5\758.bin
# 正在处理第758个文件
# K:/dataset/1000/5\759.bin
# 正在处理第759个文件
# K:/dataset/1000/5\760.bin
# 正在处理第760个文件
# K:/dataset/1000/5\761.bin
# 正在处理第761个文件
# K:/dataset/1000/5\762.bin
# 正在处理第762个文件
# K:/dataset/1000/5\763.bin
# 正在处理第763个文件
# K:/dataset/1000/5\764.bin
# 正在处理第764个文件
# K:/dataset/1000/5\765.bin
# 正在处理第765个文件
# K:/dataset/1000/5\766.bin
# 正在处理第766个文件
# K:/dataset/1000/5\767.bin
# 正在处理第767个文件
# K:/dataset/1000/5\768.bin
# 正在处理第768个文件
# K:/dataset/1000/5\769.bin
# 正在处理第769个文件
# K:/dataset/1000/5\770.bin
# 正在处理第770个文件
# K:/dataset/1000/5\771.bin
# 正在处理第771个文件
# K:/dataset/1000/5\772.bin
# 正在处理第772个文件
# K:/dataset/1000/5\773.bin
# 正在处理第773个文件
# K:/dataset/1000/5\774.bin
# 正在处理第774个文件
# K:/dataset/1000/5\775.bin
# 正在处理第775个文件
# K:/dataset/1000/5\776.bin
# 正在处理第776个文件
# K:/dataset/1000/5\777.bin
# 正在处理第777个文件
# K:/dataset/1000/5\778.bin
# 正在处理第778个文件
# K:/dataset/1000/5\779.bin
# 正在处理第779个文件
# K:/dataset/1000/5\780.bin
# 正在处理第780个文件
# K:/dataset/1000/5\781.bin
# 正在处理第781个文件
# K:/dataset/1000/5\782.bin
# 正在处理第782个文件
# K:/dataset/1000/5\783.bin
# 正在处理第783个文件
# K:/dataset/1000/5\784.bin
# 正在处理第784个文件
# K:/dataset/1000/5\785.bin
# 正在处理第785个文件
# K:/dataset/1000/5\786.bin
# 正在处理第786个文件
# K:/dataset/1000/5\787.bin
# 正在处理第787个文件
# K:/dataset/1000/5\788.bin
# 正在处理第788个文件
# K:/dataset/1000/5\789.bin
# 正在处理第789个文件
# K:/dataset/1000/5\790.bin
# 正在处理第790个文件
# K:/dataset/1000/5\791.bin
# 正在处理第791个文件
# K:/dataset/1000/5\792.bin
# 正在处理第792个文件
# K:/dataset/1000/5\793.bin
# 正在处理第793个文件
# K:/dataset/1000/5\794.bin
# 正在处理第794个文件
# K:/dataset/1000/5\795.bin
# 正在处理第795个文件
# K:/dataset/1000/5\796.bin
# 正在处理第796个文件
# K:/dataset/1000/5\797.bin
# 正在处理第797个文件
# K:/dataset/1000/5\798.bin
# 正在处理第798个文件
# K:/dataset/1000/5\799.bin
# 正在处理第799个文件
# K:/dataset/1000/5\800.bin
# 正在处理第800个文件
# K:/dataset/1000/5\801.bin
# 正在处理第801个文件
# K:/dataset/1000/5\802.bin
# 正在处理第802个文件
# K:/dataset/1000/5\803.bin
# 正在处理第803个文件
# K:/dataset/1000/5\804.bin
# 正在处理第804个文件
# K:/dataset/1000/5\805.bin
# 正在处理第805个文件
# K:/dataset/1000/5\806.bin
# 正在处理第806个文件
# K:/dataset/1000/5\807.bin
# 正在处理第807个文件
# K:/dataset/1000/5\808.bin
# 正在处理第808个文件
# K:/dataset/1000/5\809.bin
# 正在处理第809个文件
# K:/dataset/1000/5\810.bin
# 正在处理第810个文件
# K:/dataset/1000/5\811.bin
# 正在处理第811个文件
# K:/dataset/1000/5\812.bin
# 正在处理第812个文件
# K:/dataset/1000/5\813.bin
# 正在处理第813个文件
# K:/dataset/1000/5\814.bin
# 正在处理第814个文件
# K:/dataset/1000/5\815.bin
# 正在处理第815个文件
# K:/dataset/1000/5\816.bin
# 正在处理第816个文件
# K:/dataset/1000/5\817.bin
# 正在处理第817个文件
# K:/dataset/1000/5\818.bin
# 正在处理第818个文件
# K:/dataset/1000/5\819.bin
# 正在处理第819个文件
# K:/dataset/1000/5\820.bin
# 正在处理第820个文件
# K:/dataset/1000/5\821.bin
# 正在处理第821个文件
# K:/dataset/1000/5\822.bin
# 正在处理第822个文件
# K:/dataset/1000/5\823.bin
# 正在处理第823个文件
# K:/dataset/1000/5\824.bin
# 正在处理第824个文件
# K:/dataset/1000/5\825.bin
# 正在处理第825个文件
# K:/dataset/1000/5\826.bin
# 正在处理第826个文件
# K:/dataset/1000/5\827.bin
# 正在处理第827个文件
# K:/dataset/1000/5\828.bin
# 正在处理第828个文件
# K:/dataset/1000/5\829.bin
# 正在处理第829个文件
# K:/dataset/1000/5\830.bin
# 正在处理第830个文件
# K:/dataset/1000/5\831.bin
# 正在处理第831个文件
# K:/dataset/1000/5\832.bin
# 正在处理第832个文件
# K:/dataset/1000/5\833.bin
# 正在处理第833个文件
# K:/dataset/1000/5\834.bin
# 正在处理第834个文件
# K:/dataset/1000/5\835.bin
# 正在处理第835个文件
# K:/dataset/1000/5\836.bin
# 正在处理第836个文件
# K:/dataset/1000/5\837.bin
# 正在处理第837个文件
# K:/dataset/1000/5\838.bin
# 正在处理第838个文件
# K:/dataset/1000/5\839.bin
# 正在处理第839个文件
# K:/dataset/1000/5\840.bin
# 正在处理第840个文件
# K:/dataset/1000/5\841.bin
# 正在处理第841个文件
# K:/dataset/1000/5\842.bin
# 正在处理第842个文件
# K:/dataset/1000/5\843.bin
# 正在处理第843个文件
# K:/dataset/1000/5\844.bin
# 正在处理第844个文件
# K:/dataset/1000/5\845.bin
# 正在处理第845个文件
# K:/dataset/1000/5\846.bin
# 正在处理第846个文件
# K:/dataset/1000/5\847.bin
# 正在处理第847个文件
# K:/dataset/1000/5\848.bin
# 正在处理第848个文件
# K:/dataset/1000/5\849.bin
# 正在处理第849个文件
# K:/dataset/1000/5\850.bin
# 正在处理第850个文件
# K:/dataset/1000/5\851.bin
# 正在处理第851个文件
# K:/dataset/1000/5\852.bin
# 正在处理第852个文件
# K:/dataset/1000/5\853.bin
# 正在处理第853个文件
# K:/dataset/1000/5\854.bin
# 正在处理第854个文件
# K:/dataset/1000/5\855.bin
# 正在处理第855个文件
# K:/dataset/1000/5\856.bin
# 正在处理第856个文件
# K:/dataset/1000/5\857.bin
# 正在处理第857个文件
# K:/dataset/1000/5\858.bin
# 正在处理第858个文件
# K:/dataset/1000/5\859.bin
# 正在处理第859个文件
# K:/dataset/1000/5\860.bin
# 正在处理第860个文件
# K:/dataset/1000/5\861.bin
# 正在处理第861个文件
# K:/dataset/1000/5\862.bin
# 正在处理第862个文件
# K:/dataset/1000/5\863.bin
# 正在处理第863个文件
# K:/dataset/1000/5\864.bin
# 正在处理第864个文件
# K:/dataset/1000/5\865.bin
# 正在处理第865个文件
# K:/dataset/1000/5\866.bin
# 正在处理第866个文件
# K:/dataset/1000/5\867.bin
# 正在处理第867个文件
# K:/dataset/1000/5\868.bin
# 正在处理第868个文件
# K:/dataset/1000/5\869.bin
# 正在处理第869个文件
# K:/dataset/1000/5\870.bin
# 正在处理第870个文件
# K:/dataset/1000/5\871.bin
# 正在处理第871个文件
# K:/dataset/1000/5\872.bin
# 正在处理第872个文件
# K:/dataset/1000/5\873.bin
# 正在处理第873个文件
# K:/dataset/1000/5\874.bin
# 正在处理第874个文件
# K:/dataset/1000/5\875.bin
# 正在处理第875个文件
# K:/dataset/1000/5\876.bin
# 正在处理第876个文件
# K:/dataset/1000/5\877.bin
# 正在处理第877个文件
# K:/dataset/1000/5\878.bin
# 正在处理第878个文件
# K:/dataset/1000/5\879.bin
# 正在处理第879个文件
# K:/dataset/1000/5\880.bin
# 正在处理第880个文件
# K:/dataset/1000/5\881.bin
# 正在处理第881个文件
# K:/dataset/1000/5\882.bin
# 正在处理第882个文件
# K:/dataset/1000/5\883.bin
# 正在处理第883个文件
# K:/dataset/1000/5\884.bin
# 正在处理第884个文件
# K:/dataset/1000/5\885.bin
# 正在处理第885个文件
# K:/dataset/1000/5\886.bin
# 正在处理第886个文件
# K:/dataset/1000/5\887.bin
# 正在处理第887个文件
# K:/dataset/1000/5\888.bin
# 正在处理第888个文件
# K:/dataset/1000/5\889.bin
# 正在处理第889个文件
# K:/dataset/1000/5\890.bin
# 正在处理第890个文件
# K:/dataset/1000/5\891.bin
# 正在处理第891个文件
# K:/dataset/1000/5\892.bin
# 正在处理第892个文件
# K:/dataset/1000/5\893.bin
# 正在处理第893个文件
# K:/dataset/1000/5\894.bin
# 正在处理第894个文件
# K:/dataset/1000/5\895.bin
# 正在处理第895个文件
# K:/dataset/1000/5\896.bin
# 正在处理第896个文件
# K:/dataset/1000/5\897.bin
# 正在处理第897个文件
# K:/dataset/1000/5\898.bin
# 正在处理第898个文件
# K:/dataset/1000/5\899.bin
# 正在处理第899个文件
# K:/dataset/1000/5\900.bin
# 正在处理第900个文件
# K:/dataset/1000/5\901.bin
# 正在处理第901个文件
# K:/dataset/1000/5\902.bin
# 正在处理第902个文件
# K:/dataset/1000/5\903.bin
# 正在处理第903个文件
# K:/dataset/1000/5\904.bin
# 正在处理第904个文件
# K:/dataset/1000/5\905.bin
# 正在处理第905个文件
# K:/dataset/1000/5\906.bin
# 正在处理第906个文件
# K:/dataset/1000/5\907.bin
# 正在处理第907个文件
# K:/dataset/1000/5\908.bin
# 正在处理第908个文件
# K:/dataset/1000/5\909.bin
# 正在处理第909个文件
# K:/dataset/1000/5\910.bin
# 正在处理第910个文件
# K:/dataset/1000/5\911.bin
# 正在处理第911个文件
# K:/dataset/1000/5\912.bin
# 正在处理第912个文件
# K:/dataset/1000/5\913.bin
# 正在处理第913个文件
# K:/dataset/1000/5\914.bin
# 正在处理第914个文件
# K:/dataset/1000/5\915.bin
# 正在处理第915个文件
# K:/dataset/1000/5\916.bin
# 正在处理第916个文件
# K:/dataset/1000/5\917.bin
# 正在处理第917个文件
# K:/dataset/1000/5\918.bin
# 正在处理第918个文件
# K:/dataset/1000/5\919.bin
# 正在处理第919个文件
# K:/dataset/1000/5\920.bin
# 正在处理第920个文件
# K:/dataset/1000/5\921.bin
# 正在处理第921个文件
# K:/dataset/1000/5\922.bin
# 正在处理第922个文件
# K:/dataset/1000/5\923.bin
# 正在处理第923个文件
# K:/dataset/1000/5\924.bin
# 正在处理第924个文件
# K:/dataset/1000/5\925.bin
# 正在处理第925个文件
# K:/dataset/1000/5\926.bin
# 正在处理第926个文件
# K:/dataset/1000/5\927.bin
# 正在处理第927个文件
# K:/dataset/1000/5\928.bin
# 正在处理第928个文件
# K:/dataset/1000/5\929.bin
# 正在处理第929个文件
# K:/dataset/1000/5\930.bin
# 正在处理第930个文件
# K:/dataset/1000/5\931.bin
# 正在处理第931个文件
# K:/dataset/1000/5\932.bin
# 正在处理第932个文件
# K:/dataset/1000/5\933.bin
# 正在处理第933个文件
# K:/dataset/1000/5\934.bin
# 正在处理第934个文件
# K:/dataset/1000/5\935.bin
# 正在处理第935个文件
# K:/dataset/1000/5\936.bin
# 正在处理第936个文件
# K:/dataset/1000/5\937.bin
# 正在处理第937个文件
# K:/dataset/1000/5\938.bin
# 正在处理第938个文件
# K:/dataset/1000/5\939.bin
# 正在处理第939个文件
# K:/dataset/1000/5\940.bin
# 正在处理第940个文件
# K:/dataset/1000/5\941.bin
# 正在处理第941个文件
# K:/dataset/1000/5\942.bin
# 正在处理第942个文件
# K:/dataset/1000/5\943.bin
# 正在处理第943个文件
# K:/dataset/1000/5\944.bin
# 正在处理第944个文件
# K:/dataset/1000/5\945.bin
# 正在处理第945个文件
# K:/dataset/1000/5\946.bin
# 正在处理第946个文件
# K:/dataset/1000/5\947.bin
# 正在处理第947个文件
# K:/dataset/1000/5\948.bin
# 正在处理第948个文件
# K:/dataset/1000/5\949.bin
# 正在处理第949个文件
# K:/dataset/1000/5\950.bin
# 正在处理第950个文件
# K:/dataset/1000/5\951.bin
# 正在处理第951个文件
# K:/dataset/1000/5\952.bin
# 正在处理第952个文件
# K:/dataset/1000/5\953.bin
# 正在处理第953个文件
# K:/dataset/1000/5\954.bin
# 正在处理第954个文件
# K:/dataset/1000/5\955.bin
# 正在处理第955个文件
# K:/dataset/1000/5\956.bin
# 正在处理第956个文件
# K:/dataset/1000/5\957.bin
# 正在处理第957个文件
# K:/dataset/1000/5\958.bin
# 正在处理第958个文件
# K:/dataset/1000/5\959.bin
# 正在处理第959个文件
# K:/dataset/1000/5\960.bin
# 正在处理第960个文件
# K:/dataset/1000/5\961.bin
# 正在处理第961个文件
# K:/dataset/1000/5\962.bin
# 正在处理第962个文件
# K:/dataset/1000/5\963.bin
# 正在处理第963个文件
# K:/dataset/1000/5\964.bin
# 正在处理第964个文件
# K:/dataset/1000/5\965.bin
# 正在处理第965个文件
# K:/dataset/1000/5\966.bin
# 正在处理第966个文件
# K:/dataset/1000/5\967.bin
# 正在处理第967个文件
# K:/dataset/1000/5\968.bin
# 正在处理第968个文件
# K:/dataset/1000/5\969.bin
# 正在处理第969个文件
# K:/dataset/1000/5\970.bin
# 正在处理第970个文件
# K:/dataset/1000/5\971.bin
# 正在处理第971个文件
# K:/dataset/1000/5\972.bin
# 正在处理第972个文件
# K:/dataset/1000/5\973.bin
# 正在处理第973个文件
# K:/dataset/1000/5\974.bin
# 正在处理第974个文件
# K:/dataset/1000/5\975.bin
# 正在处理第975个文件
# K:/dataset/1000/5\976.bin
# 正在处理第976个文件
# K:/dataset/1000/5\977.bin
# 正在处理第977个文件
# K:/dataset/1000/5\978.bin
# 正在处理第978个文件
# K:/dataset/1000/5\979.bin
# 正在处理第979个文件
# K:/dataset/1000/5\980.bin
# 正在处理第980个文件
# K:/dataset/1000/5\981.bin
# 正在处理第981个文件
# K:/dataset/1000/5\982.bin
# 正在处理第982个文件
# K:/dataset/1000/5\983.bin
# 正在处理第983个文件
# K:/dataset/1000/5\984.bin
# 正在处理第984个文件
# K:/dataset/1000/5\985.bin
# 正在处理第985个文件
# K:/dataset/1000/5\986.bin
# 正在处理第986个文件
# K:/dataset/1000/5\987.bin
# 正在处理第987个文件
# K:/dataset/1000/5\988.bin
# 正在处理第988个文件
# K:/dataset/1000/5\989.bin
# 正在处理第989个文件
# K:/dataset/1000/5\990.bin
# 正在处理第990个文件
# K:/dataset/1000/5\991.bin
# 正在处理第991个文件
# K:/dataset/1000/5\992.bin
# 正在处理第992个文件
# K:/dataset/1000/5\993.bin
# 正在处理第993个文件
# K:/dataset/1000/5\994.bin
# 正在处理第994个文件
# K:/dataset/1000/5\995.bin
# 正在处理第995个文件
# K:/dataset/1000/5\996.bin
# 正在处理第996个文件
# K:/dataset/1000/5\997.bin
# 正在处理第997个文件
# K:/dataset/1000/5\998.bin
# 正在处理第998个文件
# K:/dataset/1000/5\999.bin
# 正在处理第999个文件
# K:/dataset/1000/5\1000.bin
# 正在处理第1000个文件
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
