# %% [markdown]
# # 设置参数
# 配置的参数,需要与采集数据时雷达配置的参数一致

# %%
import torch

n_RX = 4  # RX天线通道总数
n_samples = 64  # 采样点数
n_chirps = 255  # 每帧脉冲数
N = 64  # 距离向FFT点数
M = 64  # 多普勒向FFT点数
Q = 64  # 角度FFT

c = 3.0e8   # 光速
B = 3999.48e6  # 调频带宽
K = 99.987e12  # 调频斜率
T = B / K  # 调频周期
Tc = 140e-6  # chirp总周期
fs = 2.5e6  # 采样率
f0 = 77e9  # 初始频率
lambda_val = c / f0  # 雷达信号波长
d = lambda_val / 2  # 天线阵列间距

numADCBits = 16 # ADC位数
numLanes = 4    # 通道数
isReal = 0      # 是否为实数

# 是否静态杂波滤除
is_static_clutter_removal = 1

distance_axis = torch.arange(0, N) * fs * c / (2 * K * N)   # 距离轴
velocity_axis = torch.arange(-M/2, M/2) * lambda_val / Tc / M / 2   # 速度轴

# %% [markdown]
# # 特征提取
# 需要修改的参数有：
# - `num_classes`：分类的类别数
# - `directory_path`：数据集的路径
# ## 数据集要求
# - 数据集的文件夹名为类别的标签
#
# ```shell
# |-- 1
# |   |-- 1.bin
# |   |-- 2.bin
# |   |-- ...
# |-- 2
# |   |-- 1.bin
# |   |-- 2.bin
# |   |-- ...
# |-- ...
# ```

# %%
import os
import numpy as np
import glob
import numpy as np
import matplotlib.pyplot as plt
from RealTimeCollector.RealTimeCollector import RealTimeCollector
import scipy.io as sio

num_classes = 2 # 类别数
# directory_path = f'K:/手势识别数据集/{label}/'
# directory_path = f'K:/test/'
num_samples = 100   # 每个类别的样本数
n_frames = 30   # 每个样本的帧数
rtc = RealTimeCollector(ip_address='127.0.0.1')

# 遍历所有类别的文件夹
for label in range(1, num_classes + 1):
    print(f"当前类别为：{label}")
    directory_path = f'K:/dataset/2024_3_11/{label}'
    # 初始化变量
    range_profile = np.zeros((num_samples, n_frames, N), dtype=np.complex128)
    speed_profile = np.zeros((num_samples, n_frames, M), dtype=np.complex128)
    angle_profile = np.zeros((num_samples, n_frames, Q), dtype=np.complex128)


    bin_files = sorted(glob.glob(os.path.join(directory_path, '*.bin')))
    
    # 遍历数据集
    for i, bin_file in enumerate(bin_files):
        filename = os.path.join(directory_path, bin_file)
        print(filename)
        print(f'正在处理第{i+1}个文件')

        # 读取文件
        with open(filename, 'rb') as file:
            adcData = np.fromfile(file, dtype=np.int16)
        
        # 实部虚部结合
        adcData = adcData.reshape(numLanes*2, -1,order='F')
        adcData = adcData[[0,1,2,3],:] + 1j*adcData[[4,5,6,7],:]

        data_radar = np.reshape(adcData, (n_RX, n_samples, n_chirps, n_frames), order='F')

        temp_range_profile, temp_speed_profile, temp_angle_profile = rtc.process_frame(data_radar,clutter_removal='avg')
        
        # 压缩维度
        temp_range_profile = np.squeeze(np.mean(np.abs(temp_range_profile), axis=(0, 2))).T
        temp_speed_profile = np.squeeze(np.mean(np.abs(temp_speed_profile), axis=(0, 1))).T
        temp_angle_profile = np.squeeze(np.mean(np.abs(temp_angle_profile), axis=(1, 2))).T
        
        range_profile[i,:,:] = temp_range_profile
        speed_profile[i,:,:] = temp_speed_profile
        angle_profile[i,:,:] = temp_angle_profile
        
    # 保存.mat文件
    out_path = f'out/test/pyfeature/'
    if not os.path.exists(out_path):
        os.makedirs(out_path)
    
    sio.savemat(out_path + str(label) + '.mat', {'range_profile':range_profile,'speed_profile':speed_profile,'angle_profile':angle_profile})
# Out:
# 当前类别为：1
# K:/dataset/2024_3_11/1\100_Raw_0.bin
# 正在处理第1个文件
# K:/dataset/2024_3_11/1\10_Raw_0.bin
# 正在处理第2个文件
# K:/dataset/2024_3_11/1\11_Raw_0.bin
# 正在处理第3个文件
# K:/dataset/2024_3_11/1\12_Raw_0.bin
# 正在处理第4个文件
# K:/dataset/2024_3_11/1\13_Raw_0.bin
# 正在处理第5个文件
# K:/dataset/2024_3_11/1\14_Raw_0.bin
# 正在处理第6个文件
# K:/dataset/2024_3_11/1\15_Raw_0.bin
# 正在处理第7个文件
# K:/dataset/2024_3_11/1\16_Raw_0.bin
# 正在处理第8个文件
# K:/dataset/2024_3_11/1\17_Raw_0.bin
# 正在处理第9个文件
# K:/dataset/2024_3_11/1\18_Raw_0.bin
# 正在处理第10个文件
# K:/dataset/2024_3_11/1\19_Raw_0.bin
# 正在处理第11个文件
# K:/dataset/2024_3_11/1\1_Raw_0.bin
# 正在处理第12个文件
# K:/dataset/2024_3_11/1\20_Raw_0.bin
# 正在处理第13个文件
# K:/dataset/2024_3_11/1\21_Raw_0.bin
# 正在处理第14个文件
# K:/dataset/2024_3_11/1\22_Raw_0.bin
# 正在处理第15个文件
# K:/dataset/2024_3_11/1\23_Raw_0.bin
# 正在处理第16个文件
# K:/dataset/2024_3_11/1\24_Raw_0.bin
# 正在处理第17个文件
# K:/dataset/2024_3_11/1\25_Raw_0.bin
# 正在处理第18个文件
# K:/dataset/2024_3_11/1\26_Raw_0.bin
# 正在处理第19个文件
# K:/dataset/2024_3_11/1\27_Raw_0.bin
# 正在处理第20个文件
# K:/dataset/2024_3_11/1\28_Raw_0.bin
# 正在处理第21个文件
# K:/dataset/2024_3_11/1\29_Raw_0.bin
# 正在处理第22个文件
# K:/dataset/2024_3_11/1\2_Raw_0.bin
# 正在处理第23个文件
# K:/dataset/2024_3_11/1\30_Raw_0.bin
# 正在处理第24个文件
# K:/dataset/2024_3_11/1\31_Raw_0.bin
# 正在处理第25个文件
# K:/dataset/2024_3_11/1\32_Raw_0.bin
# 正在处理第26个文件
# K:/dataset/2024_3_11/1\33_Raw_0.bin
# 正在处理第27个文件
# K:/dataset/2024_3_11/1\34_Raw_0.bin
# 正在处理第28个文件
# K:/dataset/2024_3_11/1\35_Raw_0.bin
# 正在处理第29个文件
# K:/dataset/2024_3_11/1\36_Raw_0.bin
# 正在处理第30个文件
# K:/dataset/2024_3_11/1\37_Raw_0.bin
# 正在处理第31个文件
# K:/dataset/2024_3_11/1\38_Raw_0.bin
# 正在处理第32个文件
# K:/dataset/2024_3_11/1\39_Raw_0.bin
# 正在处理第33个文件
# K:/dataset/2024_3_11/1\3_Raw_0.bin
# 正在处理第34个文件
# K:/dataset/2024_3_11/1\40_Raw_0.bin
# 正在处理第35个文件
# K:/dataset/2024_3_11/1\41_Raw_0.bin
# 正在处理第36个文件
# K:/dataset/2024_3_11/1\42_Raw_0.bin
# 正在处理第37个文件
# K:/dataset/2024_3_11/1\43_Raw_0.bin
# 正在处理第38个文件
# K:/dataset/2024_3_11/1\44_Raw_0.bin
# 正在处理第39个文件
# K:/dataset/2024_3_11/1\45_Raw_0.bin
# 正在处理第40个文件
# K:/dataset/2024_3_11/1\46_Raw_0.bin
# 正在处理第41个文件
# K:/dataset/2024_3_11/1\47_Raw_0.bin
# 正在处理第42个文件
# K:/dataset/2024_3_11/1\48_Raw_0.bin
# 正在处理第43个文件
# K:/dataset/2024_3_11/1\49_Raw_0.bin
# 正在处理第44个文件
# K:/dataset/2024_3_11/1\4_Raw_0.bin
# 正在处理第45个文件
# K:/dataset/2024_3_11/1\50_Raw_0.bin
# 正在处理第46个文件
# K:/dataset/2024_3_11/1\51_Raw_0.bin
# 正在处理第47个文件
# K:/dataset/2024_3_11/1\52_Raw_0.bin
# 正在处理第48个文件
# K:/dataset/2024_3_11/1\53_Raw_0.bin
# 正在处理第49个文件
# K:/dataset/2024_3_11/1\54_Raw_0.bin
# 正在处理第50个文件
# K:/dataset/2024_3_11/1\55_Raw_0.bin
# 正在处理第51个文件
# K:/dataset/2024_3_11/1\56_Raw_0.bin
# 正在处理第52个文件
# K:/dataset/2024_3_11/1\57_Raw_0.bin
# 正在处理第53个文件
# K:/dataset/2024_3_11/1\58_Raw_0.bin
# 正在处理第54个文件
# K:/dataset/2024_3_11/1\59_Raw_0.bin
# 正在处理第55个文件
# K:/dataset/2024_3_11/1\5_Raw_0.bin
# 正在处理第56个文件
# K:/dataset/2024_3_11/1\60_Raw_0.bin
# 正在处理第57个文件
# K:/dataset/2024_3_11/1\61_Raw_0.bin
# 正在处理第58个文件
# K:/dataset/2024_3_11/1\62_Raw_0.bin
# 正在处理第59个文件
# K:/dataset/2024_3_11/1\63_Raw_0.bin
# 正在处理第60个文件
# K:/dataset/2024_3_11/1\64_Raw_0.bin
# 正在处理第61个文件
# K:/dataset/2024_3_11/1\65_Raw_0.bin
# 正在处理第62个文件
# K:/dataset/2024_3_11/1\66_Raw_0.bin
# 正在处理第63个文件
# K:/dataset/2024_3_11/1\67_Raw_0.bin
# 正在处理第64个文件
# K:/dataset/2024_3_11/1\68_Raw_0.bin
# 正在处理第65个文件
# K:/dataset/2024_3_11/1\69_Raw_0.bin
# 正在处理第66个文件
# K:/dataset/2024_3_11/1\6_Raw_0.bin
# 正在处理第67个文件
# K:/dataset/2024_3_11/1\70_Raw_0.bin
# 正在处理第68个文件
# K:/dataset/2024_3_11/1\71_Raw_0.bin
# 正在处理第69个文件
# K:/dataset/2024_3_11/1\72_Raw_0.bin
# 正在处理第70个文件
# K:/dataset/2024_3_11/1\73_Raw_0.bin
# 正在处理第71个文件
# K:/dataset/2024_3_11/1\74_Raw_0.bin
# 正在处理第72个文件
# K:/dataset/2024_3_11/1\75_Raw_0.bin
# 正在处理第73个文件
# K:/dataset/2024_3_11/1\76_Raw_0.bin
# 正在处理第74个文件
# K:/dataset/2024_3_11/1\77_Raw_0.bin
# 正在处理第75个文件
# K:/dataset/2024_3_11/1\78_Raw_0.bin
# 正在处理第76个文件
# K:/dataset/2024_3_11/1\79_Raw_0.bin
# 正在处理第77个文件
# K:/dataset/2024_3_11/1\7_Raw_0.bin
# 正在处理第78个文件
# K:/dataset/2024_3_11/1\80_Raw_0.bin
# 正在处理第79个文件
# K:/dataset/2024_3_11/1\81_Raw_0.bin
# 正在处理第80个文件
# K:/dataset/2024_3_11/1\82_Raw_0.bin
# 正在处理第81个文件
# K:/dataset/2024_3_11/1\83_Raw_0.bin
# 正在处理第82个文件
# K:/dataset/2024_3_11/1\84_Raw_0.bin
# 正在处理第83个文件
# K:/dataset/2024_3_11/1\85_Raw_0.bin
# 正在处理第84个文件
# K:/dataset/2024_3_11/1\86_Raw_0.bin
# 正在处理第85个文件
# K:/dataset/2024_3_11/1\87_Raw_0.bin
# 正在处理第86个文件
# K:/dataset/2024_3_11/1\88_Raw_0.bin
# 正在处理第87个文件
# K:/dataset/2024_3_11/1\89_Raw_0.bin
# 正在处理第88个文件
# K:/dataset/2024_3_11/1\8_Raw_0.bin
# 正在处理第89个文件
# K:/dataset/2024_3_11/1\90_Raw_0.bin
# 正在处理第90个文件
# K:/dataset/2024_3_11/1\91_Raw_0.bin
# 正在处理第91个文件
# K:/dataset/2024_3_11/1\92_Raw_0.bin
# 正在处理第92个文件
# K:/dataset/2024_3_11/1\93_Raw_0.bin
# 正在处理第93个文件
# K:/dataset/2024_3_11/1\94_Raw_0.bin
# 正在处理第94个文件
# K:/dataset/2024_3_11/1\95_Raw_0.bin
# 正在处理第95个文件
# K:/dataset/2024_3_11/1\96_Raw_0.bin
# 正在处理第96个文件
# K:/dataset/2024_3_11/1\97_Raw_0.bin
# 正在处理第97个文件
# K:/dataset/2024_3_11/1\98_Raw_0.bin
# 正在处理第98个文件
# K:/dataset/2024_3_11/1\99_Raw_0.bin
# 正在处理第99个文件
# K:/dataset/2024_3_11/1\9_Raw_0.bin
# 正在处理第100个文件
# 当前类别为：2
# K:/dataset/2024_3_11/2\100_Raw_0.bin
# 正在处理第1个文件
# K:/dataset/2024_3_11/2\10_Raw_0.bin
# 正在处理第2个文件
# K:/dataset/2024_3_11/2\11_Raw_0.bin
# 正在处理第3个文件
# K:/dataset/2024_3_11/2\12_Raw_0.bin
# 正在处理第4个文件
# K:/dataset/2024_3_11/2\13_Raw_0.bin
# 正在处理第5个文件
# K:/dataset/2024_3_11/2\14_Raw_0.bin
# 正在处理第6个文件
# K:/dataset/2024_3_11/2\15_Raw_0.bin
# 正在处理第7个文件
# K:/dataset/2024_3_11/2\16_Raw_0.bin
# 正在处理第8个文件
# K:/dataset/2024_3_11/2\17_Raw_0.bin
# 正在处理第9个文件
# K:/dataset/2024_3_11/2\18_Raw_0.bin
# 正在处理第10个文件
# K:/dataset/2024_3_11/2\19_Raw_0.bin
# 正在处理第11个文件
# K:/dataset/2024_3_11/2\1_Raw_0.bin
# 正在处理第12个文件
# K:/dataset/2024_3_11/2\20_Raw_0.bin
# 正在处理第13个文件
# K:/dataset/2024_3_11/2\21_Raw_0.bin
# 正在处理第14个文件
# K:/dataset/2024_3_11/2\22_Raw_0.bin
# 正在处理第15个文件
# K:/dataset/2024_3_11/2\23_Raw_0.bin
# 正在处理第16个文件
# K:/dataset/2024_3_11/2\24_Raw_0.bin
# 正在处理第17个文件
# K:/dataset/2024_3_11/2\25_Raw_0.bin
# 正在处理第18个文件
# K:/dataset/2024_3_11/2\26_Raw_0.bin
# 正在处理第19个文件
# K:/dataset/2024_3_11/2\27_Raw_0.bin
# 正在处理第20个文件
# K:/dataset/2024_3_11/2\28_Raw_0.bin
# 正在处理第21个文件
# K:/dataset/2024_3_11/2\29_Raw_0.bin
# 正在处理第22个文件
# K:/dataset/2024_3_11/2\2_Raw_0.bin
# 正在处理第23个文件
# K:/dataset/2024_3_11/2\30_Raw_0.bin
# 正在处理第24个文件
# K:/dataset/2024_3_11/2\31_Raw_0.bin
# 正在处理第25个文件
# K:/dataset/2024_3_11/2\32_Raw_0.bin
# 正在处理第26个文件
# K:/dataset/2024_3_11/2\33_Raw_0.bin
# 正在处理第27个文件
# K:/dataset/2024_3_11/2\34_Raw_0.bin
# 正在处理第28个文件
# K:/dataset/2024_3_11/2\35_Raw_0.bin
# 正在处理第29个文件
# K:/dataset/2024_3_11/2\36_Raw_0.bin
# 正在处理第30个文件
# K:/dataset/2024_3_11/2\37_Raw_0.bin
# 正在处理第31个文件
# K:/dataset/2024_3_11/2\38_Raw_0.bin
# 正在处理第32个文件
# K:/dataset/2024_3_11/2\39_Raw_0.bin
# 正在处理第33个文件
# K:/dataset/2024_3_11/2\3_Raw_0.bin
# 正在处理第34个文件
# K:/dataset/2024_3_11/2\40_Raw_0.bin
# 正在处理第35个文件
# K:/dataset/2024_3_11/2\41_Raw_0.bin
# 正在处理第36个文件
# K:/dataset/2024_3_11/2\42_Raw_0.bin
# 正在处理第37个文件
# K:/dataset/2024_3_11/2\43_Raw_0.bin
# 正在处理第38个文件
# K:/dataset/2024_3_11/2\44_Raw_0.bin
# 正在处理第39个文件
# K:/dataset/2024_3_11/2\45_Raw_0.bin
# 正在处理第40个文件
# K:/dataset/2024_3_11/2\46_Raw_0.bin
# 正在处理第41个文件
# K:/dataset/2024_3_11/2\47_Raw_0.bin
# 正在处理第42个文件
# K:/dataset/2024_3_11/2\48_Raw_0.bin
# 正在处理第43个文件
# K:/dataset/2024_3_11/2\49_Raw_0.bin
# 正在处理第44个文件
# K:/dataset/2024_3_11/2\4_Raw_0.bin
# 正在处理第45个文件
# K:/dataset/2024_3_11/2\50_Raw_0.bin
# 正在处理第46个文件
# K:/dataset/2024_3_11/2\51_Raw_0.bin
# 正在处理第47个文件
# K:/dataset/2024_3_11/2\52_Raw_0.bin
# 正在处理第48个文件
# K:/dataset/2024_3_11/2\53_Raw_0.bin
# 正在处理第49个文件
# K:/dataset/2024_3_11/2\54_Raw_0.bin
# 正在处理第50个文件
# K:/dataset/2024_3_11/2\55_Raw_0.bin
# 正在处理第51个文件
# K:/dataset/2024_3_11/2\56_Raw_0.bin
# 正在处理第52个文件
# K:/dataset/2024_3_11/2\57_Raw_0.bin
# 正在处理第53个文件
# K:/dataset/2024_3_11/2\58_Raw_0.bin
# 正在处理第54个文件
# K:/dataset/2024_3_11/2\59_Raw_0.bin
# 正在处理第55个文件
# K:/dataset/2024_3_11/2\5_Raw_0.bin
# 正在处理第56个文件
# K:/dataset/2024_3_11/2\60_Raw_0.bin
# 正在处理第57个文件
# K:/dataset/2024_3_11/2\61_Raw_0.bin
# 正在处理第58个文件
# K:/dataset/2024_3_11/2\62_Raw_0.bin
# 正在处理第59个文件
# K:/dataset/2024_3_11/2\63_Raw_0.bin
# 正在处理第60个文件
# K:/dataset/2024_3_11/2\64_Raw_0.bin
# 正在处理第61个文件
# K:/dataset/2024_3_11/2\65_Raw_0.bin
# 正在处理第62个文件
# K:/dataset/2024_3_11/2\66_Raw_0.bin
# 正在处理第63个文件
# K:/dataset/2024_3_11/2\67_Raw_0.bin
# 正在处理第64个文件
# K:/dataset/2024_3_11/2\68_Raw_0.bin
# 正在处理第65个文件
# K:/dataset/2024_3_11/2\69_Raw_0.bin
# 正在处理第66个文件
# K:/dataset/2024_3_11/2\6_Raw_0.bin
# 正在处理第67个文件
# K:/dataset/2024_3_11/2\70_Raw_0.bin
# 正在处理第68个文件
# K:/dataset/2024_3_11/2\71_Raw_0.bin
# 正在处理第69个文件
# K:/dataset/2024_3_11/2\72_Raw_0.bin
# 正在处理第70个文件
# K:/dataset/2024_3_11/2\73_Raw_0.bin
# 正在处理第71个文件
# K:/dataset/2024_3_11/2\74_Raw_0.bin
# 正在处理第72个文件
# K:/dataset/2024_3_11/2\75_Raw_0.bin
# 正在处理第73个文件
# K:/dataset/2024_3_11/2\76_Raw_0.bin
# 正在处理第74个文件
# K:/dataset/2024_3_11/2\77_Raw_0.bin
# 正在处理第75个文件
# K:/dataset/2024_3_11/2\78_Raw_0.bin
# 正在处理第76个文件
# K:/dataset/2024_3_11/2\79_Raw_0.bin
# 正在处理第77个文件
# K:/dataset/2024_3_11/2\7_Raw_0.bin
# 正在处理第78个文件
# K:/dataset/2024_3_11/2\80_Raw_0.bin
# 正在处理第79个文件
# K:/dataset/2024_3_11/2\81_Raw_0.bin
# 正在处理第80个文件
# K:/dataset/2024_3_11/2\82_Raw_0.bin
# 正在处理第81个文件
# K:/dataset/2024_3_11/2\83_Raw_0.bin
# 正在处理第82个文件
# K:/dataset/2024_3_11/2\84_Raw_0.bin
# 正在处理第83个文件
# K:/dataset/2024_3_11/2\85_Raw_0.bin
# 正在处理第84个文件
# K:/dataset/2024_3_11/2\86_Raw_0.bin
# 正在处理第85个文件
# K:/dataset/2024_3_11/2\87_Raw_0.bin
# 正在处理第86个文件
# K:/dataset/2024_3_11/2\88_Raw_0.bin
# 正在处理第87个文件
# K:/dataset/2024_3_11/2\89_Raw_0.bin
# 正在处理第88个文件
# K:/dataset/2024_3_11/2\8_Raw_0.bin
# 正在处理第89个文件
# K:/dataset/2024_3_11/2\90_Raw_0.bin
# 正在处理第90个文件
# K:/dataset/2024_3_11/2\91_Raw_0.bin
# 正在处理第91个文件
# K:/dataset/2024_3_11/2\92_Raw_0.bin
# 正在处理第92个文件
# K:/dataset/2024_3_11/2\93_Raw_0.bin
# 正在处理第93个文件
# K:/dataset/2024_3_11/2\94_Raw_0.bin
# 正在处理第94个文件
# K:/dataset/2024_3_11/2\95_Raw_0.bin
# 正在处理第95个文件
# K:/dataset/2024_3_11/2\96_Raw_0.bin
# 正在处理第96个文件
# K:/dataset/2024_3_11/2\97_Raw_0.bin
# 正在处理第97个文件
# K:/dataset/2024_3_11/2\98_Raw_0.bin
# 正在处理第98个文件
# K:/dataset/2024_3_11/2\99_Raw_0.bin
# 正在处理第99个文件
# K:/dataset/2024_3_11/2\9_Raw_0.bin
# 正在处理第100个文件

# %%
# 绘制距离-时间图
plt.figure(figsize=(10, 6))
plt.imshow(abs(range_profile[0,:,:]), cmap='jet', aspect='auto')
plt.xlabel('距离 / m')
plt.ylabel('时间 / s')
# plt.colorbar()
plt.show()

# %%
print(range_profile.shape)
# Out:
# (10, 30, 64)

# %%
from AAnet import RadarGestureNet
from AAnet import one_hot_to_label
model_path = r'K:\aio_radar\lightning_logs\version_5\checkpoints\epoch=74-step=525.ckpt'
model_path = r'K:\aio_radar\lightning_logs\version_21\checkpoints\epoch=149-step=1050.ckpt'
model = RadarGestureNet.load_from_checkpoint(model_path).to("cpu")
print(one_hot_to_label(model.encoder(torch.tensor(range_profile, dtype=torch.float32))))
# Out:
# tensor([4, 5, 3, 4, 4, 4, 3, 4, 3, 3])
